# %% [markdown]
# <a href="https://colab.research.google.com/github/luangarbin/I.A/blob/main/NASA_GH.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
resposta = requests.get('https://api.nasa.gov/mars-photos/api/v1/rovers/opportunity/photos?sol=2010&api_key=CuAHy0N4jOGGfel1p7TAM10KLmRBoBIInehXOn86')
resposta.json()
# Out:
# {'photos': [{'id': 156442,
#    'sol': 2010,
#    'camera': {'id': 17,
#     'name': 'PANCAM',
#     'rover_id': 6,
#     'full_name': 'Panoramic Camera'},
#    'img_src': 'http://mars.nasa.gov/mer/gallery/all/1/p/2010/1P306620841EFFA600P2410L2M1-BR.JPG',
#    'earth_date': '2009-09-20',
#    'rover': {'id': 6,
#     'name': 'Opportunity',
#     'landing_date': '2004-01-25',
#     'launch_date': '2003-07-07',
#     'status': 'complete',
#     'max_sol': 5111,
#     'max_date': '2018-06-11',
#     'total_photos': 198439,
#     'cameras': [{'name': 'FHAZ', 'full_name': 'Front Hazard Avoidance Camera'},
#      {'name': 'NAVCAM', 'full_name': 'Navigation Camera'},
#      {'name': 'PANCAM', 'full_name': 'Panoramic Camera'},
#      {'name': 'MINITES',
#       'full_name': 'Miniature Thermal Emission Spectrometer (Mini-TES)'},
#      {'name': 'ENTRY', 'full_name': 'Entry, Descent, and Landing Camera'},
#      {'name': 'RHAZ', 'full_name': 'Rear Hazard Avoidance Camera'}]}},
#   {'id': 156443,
#    'sol': 2010,
#    'camera': {'id': 17,
#     'name': 'PANCAM',
#     'rover_id': 6,
#     'full_name': 'Panoramic Camera'},
#    'img_src': 'http://mars.nasa.gov/mer/gallery/all/1/p/2010/1P306620841EFFA600P2410R2M1-BR.JPG',
#    'earth_date': '2009-09-20',
#    'rover': {'id': 6,
#     'name': 'Opportunity',
#     'landing_date': '2004-01-25',
#     'launch_date': '2003-07-07',
#     'status': 'complete',
#     'max_sol': 5111,
#     'max_date': '2018-06-11',
#     'total_photos': 198439,
#     'cameras': [{'name': 'FHAZ', 'full_name': 'Front Hazard Avoidance Camera'},
#      {'name': 'NAVCAM', 'full_name': 'Navigation Camera'},
#      {'name': 'PANCAM', 'full_name': 'Panoramic Camera'},
#      {'name': 'MINITES',
#       'full_name': 'Miniature Thermal Emission Spectrometer (Mini-TES)'},
#      {'name': 'ENTRY', 'full_name': 'Entry, Descent, and Landing Camera'},
#      {'name': 'RHAZ', 'full_name': 'Rear Hazard Avoidance Camera'}]}},
#   {'id': 156444,
#    'sol': 2010,
#    'camera': {'id': 17,
#     'name': 'PANCAM',
#     'rover_id': 6,
#     'full_name': 'Panoramic Camera'},
#    'img_src': 'http://mars.nasa.gov/mer/gallery/all/1/p/2010/1P306620883EFFA600P2410L5M1-BR.JPG',
#    'earth_date': '2009-09-20',
#    'rover': {'id': 6,
#     'name': 'Opportunity',
#     'landing_date': '2004-01-25',
#     'launch_date': '2003-07-07',
#     'status': 'complete',
#     'max_sol': 5111,
#     'max_date': '2018-06-11',
#     'total_photos': 198439,
#     'cameras': [{'name': 'FHAZ', 'full_name': 'Front Hazard Avoidance Camera'},
#      {'name': 'NAVCAM', 'full_name': 'Navigation Camera'},
#      {'name': 'PANCAM', 'full_name': 'Panoramic Camera'},
#      {'name': 'MINITES',
#       'full_name': 'Miniature Thermal Emission Spectrometer (Mini-TES)'},
#      {'name': 'ENTRY', 'full_name': 'Entry, Descent, and Landing Camera'},
#      {'name': 'RHAZ', 'full_name': 'Rear Hazard Avoidance Camera'}]}},
#   {'id': 156445,
#    'sol': 2010,
#    'camera': {'id': 17,
#     'name': 'PANCAM',
#     'rover_id': 6,
#     'full_name': 'Panoramic Camera'},
#    'img_src': 'http://mars.nasa.gov/mer/gallery/all/1/p/2010/1P306620911EFFA600P2410L7M1-BR.JPG',
#    'earth_date': '2009-09-20',
#    'rover': {'id': 6,
#     'name': 'Opportunity',
#     'landing_date': '2004-01-25',
#     'launch_date': '2003-07-07',
#     'status': 'complete',
#     'max_sol': 5111,
#     'max_date': '2018-06-11',
#     'total_photos': 198439,
#     'cameras': [{'name': 'FHAZ', 'full_name': 'Front Hazard Avoidance Camera'},
#      {'name': 'NAVCAM', 'full_name': 'Navigation Camera'},
#      {'name': 'PANCAM', 'full_name': 'Panoramic Camera'},
#      {'name': 'MINITES',
#       'full_name': 'Miniature Thermal Emission Spectrometer (Mini-TES)'},
#      {'name': 'ENTRY', 'full_name': 'Entry, Descent, and Landing Camera'},
#      {'name': 'RHAZ', 'full_name': 'Rear Hazard Avoidance Camera'}]}},
#   {'id': 156446,
#    'sol': 2010,
#    'camera': {'id': 17,
#     'name': 'PANCAM',
#     'rover_id': 6,
#     'full_name': 'Panoramic Camera'},
#    'img_src': 'http://mars.nasa.gov/mer/gallery/all/1/p/2010/1P306620938EFFA600P2410L2M1-BR.JPG',
#    'earth_date': '2009-09-20',
#    'rover': {'id': 6,
#     'name': 'Opportunity',
#     'landing_date': '2004-01-25',
#     'launch_date': '2003-07-07',
#     'status': 'complete',
#     'max_sol': 5111,
#     'max_date': '2018-06-11',
#     'total_photos': 198439,
#     'cameras': [{'name': 'FHAZ', 'full_name': 'Front Hazard Avoidance Camera'},
#      {'name': 'NAVCAM', 'full_name': 'Navigation Camera'},
#      {'name': 'PANCAM', 'full_name': 'Panoramic Camera'},
#      {'name': 'MINITES',
#       'full_name': 'Miniature Thermal Emission Spectrometer (Mini-TES)'},
#      {'name': 'ENTRY', 'full_name': 'Entry, Descent, and Landing Camera'},
#      {'name': 'RHAZ', 'full_name': 'Rear Hazard Avoidance Camera'}]}},
#   {'id': 156447,
#    'sol': 2010,
#    'camera': {'id': 17,
#     'name': 'PANCAM',
#     'rover_id': 6,
#     'full_name': 'Panoramic Camera'},
#    'img_src': 'http://mars.nasa.gov/mer/gallery/all/1/p/2010/1P306620938EFFA600P2410R2M1-BR.JPG',
#    'earth_date': '2009-09-20',
#    'rover': {'id': 6,
#     'name': 'Opportunity',
#     'landing_date': '2004-01-25',
#     'launch_date': '2003-07-07',
#     'status': 'complete',
#     'max_sol': 5111,
#     'max_date': '2018-06-11',
#     'total_photos': 198439,
#     'cameras': [{'name': 'FHAZ', 'full_name': 'Front Hazard Avoidance Camera'},
#      {'name': 'NAVCAM', 'full_name': 'Navigation Camera'},
#      {'name': 'PANCAM', 'full_name': 'Panoramic Camera'},
#      {'name': 'MINITES',
#       'full_name': 'Miniature Thermal Emission Spectrometer (Mini-TES)'},
#      {'name': 'ENTRY', 'full_name': 'Entry, Descent, and Landing Camera'},
#      {'name': 'RHAZ', 'full_name': 'Rear Hazard Avoidance Camera'}]}},
#   {'id': 156448,
#    'sol': 2010,
#    'camera': {'id': 17,
#     'name': 'PANCAM',
#     'rover_id': 6,
#     'full_name': 'Panoramic Camera'},
#    'img_src': 'http://mars.nasa.gov/mer/gallery/all/1/p/2010/1P306620938EFFA600P2410R2M2-BR.JPG',
#    'earth_date': '2009-09-20',
#    'rover': {'id': 6,
#     'name': 'Opportunity',
#     'landing_date': '2004-01-25',
#     'launch_date': '2003-07-07',
#     'status': 'complete',
#     'max_sol': 5111,
#     'max_date': '2018-06-11',
#     'total_photos': 198439,
#     'cameras': [{'name': 'FHAZ', 'full_name': 'Front Hazard Avoidance Camera'},
#      {'name': 'NAVCAM', 'full_name': 'Navigation Camera'},
#      {'name': 'PANCAM', 'full_name': 'Panoramic Camera'},
#      {'name': 'MINITES',
#       'full_name': 'Miniature Thermal Emission Spectrometer (Mini-TES)'},
#      {'name': 'ENTRY', 'full_name': 'Entry, Descent, and Landing Camera'},
#      {'name': 'RHAZ', 'full_name': 'Rear Hazard Avoidance Camera'}]}},
#   {'id': 156449,
#    'sol': 2010,
#    'camera': {'id': 17,
#     'name': 'PANCAM',
#     'rover_id': 6,
#     'full_name': 'Panoramic Camera'},
#    'img_src': 'http://mars.nasa.gov/mer/gallery/all/1/p/2010/1P306620969EFFA600P2410L5M1-BR.JPG',
#    'earth_date': '2009-09-20',
#    'rover': {'id': 6,
#     'name': 'Opportunity',
#     'landing_date': '2004-01-25',
#     'launch_date': '2003-07-07',
#     'status': 'complete',
#     'max_sol': 5111,
#     'max_date': '2018-06-11',
#     'total_photos': 198439,
#     'cameras': [{'name': 'FHAZ', 'full_name': 'Front Hazard Avoidance Camera'},
#      {'name': 'NAVCAM', 'full_name': 'Navigation Camera'},
#      {'name': 'PANCAM', 'full_name': 'Panoramic Camera'},
#      {'name': 'MINITES',
#       'full_name': 'Miniature Thermal Emission Spectrometer (Mini-TES)'},
#      {'name': 'ENTRY', 'full_name': 'Entry, Descent, and Landing Camera'},
#      {'name': 'RHAZ', 'full_name': 'Rear Hazard Avoidance Camera'}]}},
#   {'id': 156450,
#    'sol': 2010,
#    'camera': {'id': 17,
#     'name': 'PANCAM',
#     'rover_id': 6,
#     'full_name': 'Panoramic Camera'},
#    'img_src': 'http://mars.nasa.gov/mer/gallery/all/1/p/2010/1P306620997EFFA600P2410L7M1-BR.JPG',
#    'earth_date': '2009-09-20',
#    'rover': {'id': 6,
#     'name': 'Opportunity',
#     'landing_date': '2004-01-25',
#     'launch_date': '2003-07-07',
#     'status': 'complete',
#     'max_sol': 5111,
#     'max_date': '2018-06-11',
#     'total_photos': 198439,
#     'cameras': [{'name': 'FHAZ', 'full_name': 'Front Hazard Avoidance Camera'},
#      {'name': 'NAVCAM', 'full_name': 'Navigation Camera'},
#      {'name': 'PANCAM', 'full_name': 'Panoramic Camera'},
#      {'name': 'MINITES',
#       'full_name': 'Miniature Thermal Emission Spectrometer (Mini-TES)'},
#      {'name': 'ENTRY', 'full_name': 'Entry, Descent, and Landing Camera'},
#      {'name': 'RHAZ', 'full_name': 'Rear Hazard Avoidance Camera'}]}},
#   {'id': 156451,
#    'sol': 2010,
#    'camera': {'id': 17,
#     'name': 'PANCAM',
#     'rover_id': 6,
#     'full_name': 'Panoramic Camera'},
#    'img_src': 'http://mars.nasa.gov/mer/gallery/all/1/p/2010/1P306621018EFFA600P2410L2M1-BR.JPG',
#    'earth_date': '2009-09-20',
#    'rover': {'id': 6,
#     'name': 'Opportunity',
#     'landing_date': '2004-01-25',
#     'launch_date': '2003-07-07',
#     'status': 'complete',
#     'max_sol': 5111,
#     'max_date': '2018-06-11',
#     'total_photos': 198439,
#     'cameras': [{'name': 'FHAZ', 'full_name': 'Front Hazard Avoidance Camera'},
#      {'name': 'NAVCAM', 'full_name': 'Navigation Camera'},
#      {'name': 'PANCAM', 'full_name': 'Panoramic Camera'},
#      {'name': 'MINITES',
#       'full_name': 'Miniature Thermal Emission Spectrometer (Mini-TES)'},
#      {'name': 'ENTRY', 'full_name': 'Entry, Descent, and Landing Camera'},
#      {'name': 'RHAZ', 'full_name': 'Rear Hazard Avoidance Camera'}]}},
#   {'id': 156452,
#    'sol': 2010,
#    'camera': {'id': 17,
#     'name': 'PANCAM',
#     'rover_id': 6,
#     'full_name': 'Panoramic Camera'},
#    'img_src': 'http://mars.nasa.gov/mer/gallery/all/1/p/2010/1P306621018EFFA600P2410R2M1-BR.JPG',
#    'earth_date': '2009-09-20',
#    'rover': {'id': 6,
#     'name': 'Opportunity',
#     'landing_date': '2004-01-25',
#     'launch_date': '2003-07-07',
#     'status': 'complete',
#     'max_sol': 5111,
#     'max_date': '2018-06-11',
#     'total_photos': 198439,
#     'cameras': [{'name': 'FHAZ', 'full_name': 'Front Hazard Avoidance Camera'},
#      {'name': 'NAVCAM', 'full_name': 'Navigation Camera'},
#      {'name': 'PANCAM', 'full_name': 'Panoramic Camera'},
#      {'name': 'MINITES',
#       'full_name': 'Miniature Thermal Emission Spectrometer (Mini-TES)'},
#      {'name': 'ENTRY', 'full_name': 'Entry, Descent, and Landing Camera'},
#      {'name': 'RHAZ', 'full_name': 'Rear Hazard Avoidance Camera'}]}},
#   {'id': 156453,
#    'sol': 2010,
#    'camera': {'id': 17,
#     'name': 'PANCAM',
#     'rover_id': 6,
#     'full_name': 'Panoramic Camera'},
#    'img_src': 'http://mars.nasa.gov/mer/gallery/all/1/p/2010/1P306621049EFFA600P2410L5M1-BR.JPG',
#    'earth_date': '2009-09-20',
#    'rover': {'id': 6,
#     'name': 'Opportunity',
#     'landing_date': '2004-01-25',
#     'launch_date': '2003-07-07',
#     'status': 'complete',
#     'max_sol': 5111,
#     'max_date': '2018-06-11',
#     'total_photos': 198439,
#     'cameras': [{'name': 'FHAZ', 'full_name': 'Front Hazard Avoidance Camera'},
#      {'name': 'NAVCAM', 'full_name': 'Navigation Camera'},
#      {'name': 'PANCAM', 'full_name': 'Panoramic Camera'},
#      {'name': 'MINITES',
#       'full_name': 'Miniature Thermal Emission Spectrometer (Mini-TES)'},
#      {'name': 'ENTRY', 'full_name': 'Entry, Descent, and Landing Camera'},
#      {'name': 'RHAZ', 'full_name': 'Rear Hazard Avoidance Camera'}]}},
#   {'id': 156454,
#    'sol': 2010,
#    'camera': {'id': 17,
#     'name': 'PANCAM',
#     'rover_id': 6,
#     'full_name': 'Panoramic Camera'},
#    'img_src': 'http://mars.nasa.gov/mer/gallery/all/1/p/2010/1P306621077EFFA600P2410L7M1-BR.JPG',
#    'earth_date': '2009-09-20',
#    'rover': {'id': 6,
#     'name': 'Opportunity',
#     'landing_date': '2004-01-25',
#     'launch_date': '2003-07-07',
#     'status': 'complete',
#     'max_sol': 5111,
#     'max_date': '2018-06-11',
#     'total_photos': 198439,
#     'cameras': [{'name': 'FHAZ', 'full_name': 'Front Hazard Avoidance Camera'},
#      {'name': 'NAVCAM', 'full_name': 'Navigation Camera'},
#      {'name': 'PANCAM', 'full_name': 'Panoramic Camera'},
#      {'name': 'MINITES',
#       'full_name': 'Miniature Thermal Emission Spectrometer (Mini-TES)'},
#      {'name': 'ENTRY', 'full_name': 'Entry, Descent, and Landing Camera'},
#      {'name': 'RHAZ', 'full_name': 'Rear Hazard Avoidance Camera'}]}},
#   {'id': 156455,
#    'sol': 2010,
#    'camera': {'id': 17,
#     'name': 'PANCAM',
#     'rover_id': 6,
#     'full_name': 'Panoramic Camera'},
#    'img_src': 'http://mars.nasa.gov/mer/gallery/all/1/p/2010/1P306621124EFFA600P2410L2M1-BR.JPG',
#    'earth_date': '2009-09-20',
#    'rover': {'id': 6,
#     'name': 'Opportunity',
#     'landing_date': '2004-01-25',
#     'launch_date': '2003-07-07',
#     'status': 'complete',
#     'max_sol': 5111,
#     'max_date': '2018-06-11',
#     'total_photos': 198439,
#     'cameras': [{'name': 'FHAZ', 'full_name': 'Front Hazard Avoidance Camera'},
#      {'name': 'NAVCAM', 'full_name': 'Navigation Camera'},
#      {'name': 'PANCAM', 'full_name': 'Panoramic Camera'},
#      {'name': 'MINITES',
#       'full_name': 'Miniature Thermal Emission Spectrometer (Mini-TES)'},
#      {'name': 'ENTRY', 'full_name': 'Entry, Descent, and Landing Camera'},
#      {'name': 'RHAZ', 'full_name': 'Rear Hazard Avoidance Camera'}]}},
#   {'id': 156456,
#    'sol': 2010,
#    'camera': {'id': 17,
#     'name': 'PANCAM',
#     'rover_id': 6,
#     'full_name': 'Panoramic Camera'},
#    'img_src': 'http://mars.nasa.gov/mer/gallery/all/1/p/2010/1P306621124EFFA600P2410R2M1-BR.JPG',
#    'earth_date': '2009-09-20',
#    'rover': {'id': 6,
#     'name': 'Opportunity',
#     'landing_date': '2004-01-25',
#     'launch_date': '2003-07-07',
#     'status': 'complete',
#     'max_sol': 5111,
#     'max_date': '2018-06-11',
#     'total_photos': 198439,
#     'cameras': [{'name': 'FHAZ', 'full_name': 'Front Hazard Avoidance Camera'},
#      {'name': 'NAVCAM', 'full_name': 'Navigation Camera'},
#      {'name': 'PANCAM', 'full_name': 'Panoramic Camera'},
#      {'name': 'MINITES',
#       'full_name': 'Miniature Thermal Emission Spectrometer (Mini-TES)'},
#      {'name': 'ENTRY', 'full_name': 'Entry, Descent, and Landing Camera'},
#      {'name': 'RHAZ', 'full_name': 'Rear Hazard Avoidance Camera'}]}},
#   {'id': 156457,
#    'sol': 2010,
#    'camera': {'id': 17,
#     'name': 'PANCAM',
#     'rover_id': 6,
#     'full_name': 'Panoramic Camera'},
#    'img_src': 'http://mars.nasa.gov/mer/gallery/all/1/p/2010/1P306621228EFFA600P2410L5M1-BR.JPG',
#    'earth_date': '2009-09-20',
#    'rover': {'id': 6,
#     'name': 'Opportunity',
#     'landing_date': '2004-01-25',
#     'launch_date': '2003-07-07',
#     'status': 'complete',
#     'max_sol': 5111,
#     'max_date': '2018-06-11',
#     'total_photos': 198439,
#     'cameras': [{'name': 'FHAZ', 'full_name': 'Front Hazard Avoidance Camera'},
#      {'name': 'NAVCAM', 'full_name': 'Navigation Camera'},
#      {'name': 'PANCAM', 'full_name': 'Panoramic Camera'},
#      {'name': 'MINITES',
#       'full_name': 'Miniature Thermal Emission Spectrometer (Mini-TES)'},
#      {'name': 'ENTRY', 'full_name': 'Entry, Descent, and Landing Camera'},
#      {'name': 'RHAZ', 'full_name': 'Rear Hazard Avoidance Camera'}]}},
#   {'id': 156458,
#    'sol': 2010,
#    'camera': {'id': 17,
#     'name': 'PANCAM',
#     'rover_id': 6,
#     'full_name': 'Panoramic Camera'},
#    'img_src': 'http://mars.nasa.gov/mer/gallery/all/1/p/2010/1P306621299EFFA600P2410L7M1-BR.JPG',
#    'earth_date': '2009-09-20',
#    'rover': {'id': 6,
#     'name': 'Opportunity',
#     'landing_date': '2004-01-25',
#     'launch_date': '2003-07-07',
#     'status': 'complete',
#     'max_sol': 5111,
#     'max_date': '2018-06-11',
#     'total_photos': 198439,
#     'cameras': [{'name': 'FHAZ', 'full_name': 'Front Hazard Avoidance Camera'},
#      {'name': 'NAVCAM', 'full_name': 'Navigation Camera'},
#      {'name': 'PANCAM', 'full_name': 'Panoramic Camera'},
#      {'name': 'MINITES',
#       'full_name': 'Miniature Thermal Emission Spectrometer (Mini-TES)'},
#      {'name': 'ENTRY', 'full_name': 'Entry, Descent, and Landing Camera'},
#      {'name': 'RHAZ', 'full_name': 'Rear Hazard Avoidance Camera'}]}},
#   {'id': 156459,
#    'sol': 2010,
#    'camera': {'id': 17,
#     'name': 'PANCAM',
#     'rover_id': 6,
#     'full_name': 'Panoramic Camera'},
#    'img_src': 'http://mars.nasa.gov/mer/gallery/all/1/p/2010/1P306621476EFFA600P2410L2M1-BR.JPG',
#    'earth_date': '2009-09-20',
#    'rover': {'id': 6,
#     'name': 'Opportunity',
#     'landing_date': '2004-01-25',
#     'launch_date': '2003-07-07',
#     'status': 'complete',
#     'max_sol': 5111,
#     'max_date': '2018-06-11',
#     'total_photos': 198439,
#     'cameras': [{'name': 'FHAZ', 'full_name': 'Front Hazard Avoidance Camera'},
#      {'name': 'NAVCAM', 'full_name': 'Navigation Camera'},
#      {'name': 'PANCAM', 'full_name': 'Panoramic Camera'},
#      {'name': 'MINITES',
#       'full_name': 'Miniature Thermal Emission Spectrometer (Mini-TES)'},
#      {'name': 'ENTRY', 'full_name': 'Entry, Descent, and Landing Camera'},
#      {'name': 'RHAZ', 'full_name': 'Rear Hazard Avoidance Camera'}]}},
#   {'id': 156460,
#    'sol': 2010,
#    'camera': {'id': 17,
#     'name': 'PANCAM',
#     'rover_id': 6,
#     'full_name': 'Panoramic Camera'},
#    'img_src': 'http://mars.nasa.gov/mer/gallery/all/1/p/2010/1P306621476EFFA600P2410R2M1-BR.JPG',
#    'earth_date': '2009-09-20',
#    'rover': {'id': 6,
#     'name': 'Opportunity',
#     'landing_date': '2004-01-25',
#     'launch_date': '2003-07-07',
#     'status': 'complete',
#     'max_sol': 5111,
#     'max_date': '2018-06-11',
#     'total_photos': 198439,
#     'cameras': [{'name': 'FHAZ', 'full_name': 'Front Hazard Avoidance Camera'},
#      {'name': 'NAVCAM', 'full_name': 'Navigation Camera'},
#      {'name': 'PANCAM', 'full_name': 'Panoramic Camera'},
#      {'name': 'MINITES',
#       'full_name': 'Miniature Thermal Emission Spectrometer (Mini-TES)'},
#      {'name': 'ENTRY', 'full_name': 'Entry, Descent, and Landing Camera'},
#      {'name': 'RHAZ', 'full_name': 'Rear Hazard Avoidance Camera'}]}},
#   {'id': 156461,
#    'sol': 2010,
#    'camera': {'id': 17,
#     'name': 'PANCAM',
#     'rover_id': 6,
#     'full_name': 'Panoramic Camera'},
#    'img_src': 'http://mars.nasa.gov/mer/gallery/all/1/p/2010/1P306621567EFFA600P2410L5M1-BR.JPG',
#    'earth_date': '2009-09-20',
#    'rover': {'id': 6,
#     'name': 'Opportunity',
#     'landing_date': '2004-01-25',
#     'launch_date': '2003-07-07',
#     'status': 'complete',
#     'max_sol': 5111,
#     'max_date': '2018-06-11',
#     'total_photos': 198439,
#     'cameras': [{'name': 'FHAZ', 'full_name': 'Front Hazard Avoidance Camera'},
#      {'name': 'NAVCAM', 'full_name': 'Navigation Camera'},
#      {'name': 'PANCAM', 'full_name': 'Panoramic Camera'},
#      {'name': 'MINITES',
#       'full_name': 'Miniature Thermal Emission Spectrometer (Mini-TES)'},
#      {'name': 'ENTRY', 'full_name': 'Entry, Descent, and Landing Camera'},
#      {'name': 'RHAZ', 'full_name': 'Rear Hazard Avoidance Camera'}]}},
#   {'id': 156462,
#    'sol': 2010,
#    'camera': {'id': 17,
#     'name': 'PANCAM',
#     'rover_id': 6,
#     'full_name': 'Panoramic Camera'},
#    'img_src': 'http://mars.nasa.gov/mer/gallery/all/1/p/2010/1P306621646EFFA600P2410L7M1-BR.JPG',
#    'earth_date': '2009-09-20',
#    'rover': {'id': 6,
#     'name': 'Opportunity',
#     'landing_date': '2004-01-25',
#     'launch_date': '2003-07-07',
#     'status': 'complete',
#     'max_sol': 5111,
#     'max_date': '2018-06-11',
#     'total_photos': 198439,
#     'cameras': [{'name': 'FHAZ', 'full_name': 'Front Hazard Avoidance Camera'},
#      {'name': 'NAVCAM', 'full_name': 'Navigation Camera'},
#      {'name': 'PANCAM', 'full_name': 'Panoramic Camera'},
#      {'name': 'MINITES',
#       'full_name': 'Miniature Thermal Emission Spectrometer (Mini-TES)'},
#      {'name': 'ENTRY', 'full_name': 'Entry, Descent, and Landing Camera'},
#      {'name': 'RHAZ', 'full_name': 'Rear Hazard Avoidance Camera'}]}},
#   {'id': 156463,
#    'sol': 2010,
#    'camera': {'id': 17,
#     'name': 'PANCAM',
#     'rover_id': 6,
#     'full_name': 'Panoramic Camera'},
#    'img_src': 'http://mars.nasa.gov/mer/gallery/all/1/p/2010/1P306621829EFFA600P2410L2M1-BR.JPG',
#    'earth_date': '2009-09-20',
#    'rover': {'id': 6,
#     'name': 'Opportunity',
#     'landing_date': '2004-01-25',
#     'launch_date': '2003-07-07',
#     'status': 'complete',
#     'max_sol': 5111,
#     'max_date': '2018-06-11',
#     'total_photos': 198439,
#     'cameras': [{'name': 'FHAZ', 'full_name': 'Front Hazard Avoidance Camera'},
#      {'name': 'NAVCAM', 'full_name': 'Navigation Camera'},
#      {'name': 'PANCAM', 'full_name': 'Panoramic Camera'},
#      {'name': 'MINITES',
#       'full_name': 'Miniature Thermal Emission Spectrometer (Mini-TES)'},
#      {'name': 'ENTRY', 'full_name': 'Entry, Descent, and Landing Camera'},
#      {'name': 'RHAZ', 'full_name': 'Rear Hazard Avoidance Camera'}]}},
#   {'id': 156464,
#    'sol': 2010,
#    'camera': {'id': 17,
#     'name': 'PANCAM',
#     'rover_id': 6,
#     'full_name': 'Panoramic Camera'},
#    'img_src': 'http://mars.nasa.gov/mer/gallery/all/1/p/2010/1P306621829EFFA600P2410R2M1-BR.JPG',
#    'earth_date': '2009-09-20',
#    'rover': {'id': 6,
#     'name': 'Opportunity',
#     'landing_date': '2004-01-25',
#     'launch_date': '2003-07-07',
#     'status': 'complete',
#     'max_sol': 5111,
#     'max_date': '2018-06-11',
#     'total_photos': 198439,
#     'cameras': [{'name': 'FHAZ', 'full_name': 'Front Hazard Avoidance Camera'},
#      {'name': 'NAVCAM', 'full_name': 'Navigation Camera'},
#      {'name': 'PANCAM', 'full_name': 'Panoramic Camera'},
#      {'name': 'MINITES',
#       'full_name': 'Miniature Thermal Emission Spectrometer (Mini-TES)'},
#      {'name': 'ENTRY', 'full_name': 'Entry, Descent, and Landing Camera'},
#      {'name': 'RHAZ', 'full_name': 'Rear Hazard Avoidance Camera'}]}},
#   {'id': 156465,
#    'sol': 2010,
#    'camera': {'id': 17,
#     'name': 'PANCAM',
#     'rover_id': 6,
#     'full_name': 'Panoramic Camera'},
#    'img_src': 'http://mars.nasa.gov/mer/gallery/all/1/p/2010/1P306621914EFFA600P2410L5M1-BR.JPG',
#    'earth_date': '2009-09-20',
#    'rover': {'id': 6,
#     'name': 'Opportunity',
#     'landing_date': '2004-01-25',
#     'launch_date': '2003-07-07',
#     'status': 'complete',
#     'max_sol': 5111,
#     'max_date': '2018-06-11',
#     'total_photos': 198439,
#     'cameras': [{'name': 'FHAZ', 'full_name': 'Front Hazard Avoidance Camera'},
#      {'name': 'NAVCAM', 'full_name': 'Navigation Camera'},
#      {'name': 'PANCAM', 'full_name': 'Panoramic Camera'},
#      {'name': 'MINITES',
#       'full_name': 'Miniature Thermal Emission Spectrometer (Mini-TES)'},
#      {'name': 'ENTRY', 'full_name': 'Entry, Descent, and Landing Camera'},
#      {'name': 'RHAZ', 'full_name': 'Rear Hazard Avoidance Camera'}]}},
#   {'id': 156466,
#    'sol': 2010,
#    'camera': {'id': 17,
#     'name': 'PANCAM',
#     'rover_id': 6,
#     'full_name': 'Panoramic Camera'},
#    'img_src': 'http://mars.nasa.gov/mer/gallery/all/1/p/2010/1P306621998EFFA600P2410L7M1-BR.JPG',
#    'earth_date': '2009-09-20',
#    'rover': {'id': 6,
#     'name': 'Opportunity',
#     'landing_date': '2004-01-25',
#     'launch_date': '2003-07-07',
#     'status': 'complete',
#     'max_sol': 5111,
#     'max_date': '2018-06-11',
#     'total_photos': 198439,
#     'cameras': [{'name': 'FHAZ', 'full_name': 'Front Hazard Avoidance Camera'},
#      {'name': 'NAVCAM', 'full_name': 'Navigation Camera'},
#      {'name': 'PANCAM', 'full_name': 'Panoramic Camera'},
#      {'name': 'MINITES',
#       'full_name': 'Miniature Thermal Emission Spectrometer (Mini-TES)'},
#      {'name': 'ENTRY', 'full_name': 'Entry, Descent, and Landing Camera'},
#      {'name': 'RHAZ', 'full_name': 'Rear Hazard Avoidance Camera'}]}},
#   {'id': 156467,
#    'sol': 2010,
#    'camera': {'id': 17,
#     'name': 'PANCAM',
#     'rover_id': 6,
#     'full_name': 'Panoramic Camera'},
#    'img_src': 'http://mars.nasa.gov/mer/gallery/all/1/p/2010/1P306622172EFFA600P2410L2M1-BR.JPG',
#    'earth_date': '2009-09-20',
#    'rover': {'id': 6,
#     'name': 'Opportunity',
#     'landing_date': '2004-01-25',
#     'launch_date': '2003-07-07',
#     'status': 'complete',
#     'max_sol': 5111,
#     'max_date': '2018-06-11',
#     'total_photos': 198439,
#     'cameras': [{'name': 'FHAZ', 'full_name': 'Front Hazard Avoidance Camera'},
#      {'name': 'NAVCAM', 'full_name': 'Navigation Camera'},
#      {'name': 'PANCAM', 'full_name': 'Panoramic Camera'},
#      {'name': 'MINITES',
#       'full_name': 'Miniature Thermal Emission Spectrometer (Mini-TES)'},
#      {'name': 'ENTRY', 'full_name': 'Entry, Descent, and Landing Camera'},
#      {'name': 'RHAZ', 'full_name': 'Rear Hazard Avoidance Camera'}]}},
#   {'id': 156468,
#    'sol': 2010,
#    'camera': {'id': 17,
#     'name': 'PANCAM',
#     'rover_id': 6,
#     'full_name': 'Panoramic Camera'},
#    'img_src': 'http://mars.nasa.gov/mer/gallery/all/1/p/2010/1P306622172EFFA600P2410R2M1-BR.JPG',
#    'earth_date': '2009-09-20',
#    'rover': {'id': 6,
#     'name': 'Opportunity',
#     'landing_date': '2004-01-25',
#     'launch_date': '2003-07-07',
#     'status': 'complete',
#     'max_sol': 5111,
#     'max_date': '2018-06-11',
#     'total_photos': 198439,
#     'cameras': [{'name': 'FHAZ', 'full_name': 'Front Hazard Avoidance Camera'},
#      {'name': 'NAVCAM', 'full_name': 'Navigation Camera'},
#      {'name': 'PANCAM', 'full_name': 'Panoramic Camera'},
#      {'name': 'MINITES',
#       'full_name': 'Miniature Thermal Emission Spectrometer (Mini-TES)'},
#      {'name': 'ENTRY', 'full_name': 'Entry, Descent, and Landing Camera'},
#      {'name': 'RHAZ', 'full_name': 'Rear Hazard Avoidance Camera'}]}},
#   {'id': 156469,
#    'sol': 2010,
#    'camera': {'id': 17,
#     'name': 'PANCAM',
#     'rover_id': 6,
#     'full_name': 'Panoramic Camera'},
#    'img_src': 'http://mars.nasa.gov/mer/gallery/all/1/p/2010/1P306622242EFFA600P2410L5M1-BR.JPG',
#    'earth_date': '2009-09-20',
#    'rover': {'id': 6,
#     'name': 'Opportunity',
#     'landing_date': '2004-01-25',
#     'launch_date': '2003-07-07',
#     'status': 'complete',
#     'max_sol': 5111,
#     'max_date': '2018-06-11',
#     'total_photos': 198439,
#     'cameras': [{'name': 'FHAZ', 'full_name': 'Front Hazard Avoidance Camera'},
#      {'name': 'NAVCAM', 'full_name': 'Navigation Camera'},
#      {'name': 'PANCAM', 'full_name': 'Panoramic Camera'},
#      {'name': 'MINITES',
#       'full_name': 'Miniature Thermal Emission Spectrometer (Mini-TES)'},
#      {'name': 'ENTRY', 'full_name': 'Entry, Descent, and Landing Camera'},
#      {'name': 'RHAZ', 'full_name': 'Rear Hazard Avoidance Camera'}]}},
#   {'id': 156470,
#    'sol': 2010,
#    'camera': {'id': 17,
#     'name': 'PANCAM',
#     'rover_id': 6,
#     'full_name': 'Panoramic Camera'},
#    'img_src': 'http://mars.nasa.gov/mer/gallery/all/1/p/2010/1P306622320EFFA600P2410L7M1-BR.JPG',
#    'earth_date': '2009-09-20',
#    'rover': {'id': 6,
#     'name': 'Opportunity',
#     'landing_date': '2004-01-25',
#     'launch_date': '2003-07-07',
#     'status': 'complete',
#     'max_sol': 5111,
#     'max_date': '2018-06-11',
#     'total_photos': 198439,
#     'cameras': [{'name': 'FHAZ', 'full_name': 'Front Hazard Avoidance Camera'},
#      {'name': 'NAVCAM', 'full_name': 'Navigation Camera'},
#      {'name': 'PANCAM', 'full_name': 'Panoramic Camera'},
#      {'name': 'MINITES',
#       'full_name': 'Miniature Thermal Emission Spectrometer (Mini-TES)'},
#      {'name': 'ENTRY', 'full_name': 'Entry, Descent, and Landing Camera'},
#      {'name': 'RHAZ', 'full_name': 'Rear Hazard Avoidance Camera'}]}},
#   {'id': 156471,
#    'sol': 2010,
#    'camera': {'id': 17,
#     'name': 'PANCAM',
#     'rover_id': 6,
#     'full_name': 'Panoramic Camera'},
#    'img_src': 'http://mars.nasa.gov/mer/gallery/all/1/p/2010/1P306622480EFFA600P2410L2M1-BR.JPG',
#    'earth_date': '2009-09-20',
#    'rover': {'id': 6,
#     'name': 'Opportunity',
#     'landing_date': '2004-01-25',
#     'launch_date': '2003-07-07',
#     'status': 'complete',
#     'max_sol': 5111,
#     'max_date': '2018-06-11',
#     'total_photos': 198439,
#     'cameras': [{'name': 'FHAZ', 'full_name': 'Front Hazard Avoidance Camera'},
#      {'name': 'NAVCAM', 'full_name': 'Navigation Camera'},
#      {'name': 'PANCAM', 'full_name': 'Panoramic Camera'},
#      {'name': 'MINITES',
#       'full_name': 'Miniature Thermal Emission Spectrometer (Mini-TES)'},
#      {'name': 'ENTRY', 'full_name': 'Entry, Descent, and Landing Camera'},
#      {'name': 'RHAZ', 'full_name': 'Rear Hazard Avoidance Camera'}]}},
#   {'id': 156472,
#    'sol': 2010,
#    'camera': {'id': 17,
#     'name': 'PANCAM',
#     'rover_id': 6,
#     'full_name': 'Panoramic Camera'},
#    'img_src': 'http://mars.nasa.gov/mer/gallery/all/1/p/2010/1P306622480EFFA600P2410R2M1-BR.JPG',
#    'earth_date': '2009-09-20',
#    'rover': {'id': 6,
#     'name': 'Opportunity',
#     'landing_date': '2004-01-25',
#     'launch_date': '2003-07-07',
#     'status': 'complete',
#     'max_sol': 5111,
#     'max_date': '2018-06-11',
#     'total_photos': 198439,
#     'cameras': [{'name': 'FHAZ', 'full_name': 'Front Hazard Avoidance Camera'},
#      {'name': 'NAVCAM', 'full_name': 'Navigation Camera'},
#      {'name': 'PANCAM', 'full_name': 'Panoramic Camera'},
#      {'name': 'MINITES',
#       'full_name': 'Miniature Thermal Emission Spectrometer (Mini-TES)'},
#      {'name': 'ENTRY', 'full_name': 'Entry, Descent, and Landing Camera'},
#      {'name': 'RHAZ', 'full_name': 'Rear Hazard Avoidance Camera'}]}},
#   {'id': 156473,
#    'sol': 2010,
#    'camera': {'id': 17,
#     'name': 'PANCAM',
#     'rover_id': 6,
#     'full_name': 'Panoramic Camera'},
#    'img_src': 'http://mars.nasa.gov/mer/gallery/all/1/p/2010/1P306622571EFFA600P2410L5M1-BR.JPG',
#    'earth_date': '2009-09-20',
#    'rover': {'id': 6,
#     'name': 'Opportunity',
#     'landing_date': '2004-01-25',
#     'launch_date': '2003-07-07',
#     'status': 'complete',
#     'max_sol': 5111,
#     'max_date': '2018-06-11',
#     'total_photos': 198439,
#     'cameras': [{'name': 'FHAZ', 'full_name': 'Front Hazard Avoidance Camera'},
#      {'name': 'NAVCAM', 'full_name': 'Navigation Camera'},
#      {'name': 'PANCAM', 'full_name': 'Panoramic Camera'},
#      {'name': 'MINITES',
#       'full_name': 'Miniature Thermal Emission Spectrometer (Mini-TES)'},
#      {'name': 'ENTRY', 'full_name': 'Entry, Descent, and Landing Camera'},
#      {'name': 'RHAZ', 'full_name': 'Rear Hazard Avoidance Camera'}]}},
#   {'id': 156474,
#    'sol': 2010,
#    'camera': {'id': 17,
#     'name': 'PANCAM',
#     'rover_id': 6,
#     'full_name': 'Panoramic Camera'},
#    'img_src': 'http://mars.nasa.gov/mer/gallery/all/1/p/2010/1P306622645EFFA600P2410L7M1-BR.JPG',
#    'earth_date': '2009-09-20',
#    'rover': {'id': 6,
#     'name': 'Opportunity',
#     'landing_date': '2004-01-25',
#     'launch_date': '2003-07-07',
#     'status': 'complete',
#     'max_sol': 5111,
#     'max_date': '2018-06-11',
#     'total_photos': 198439,
#     'cameras': [{'name': 'FHAZ', 'full_name': 'Front Hazard Avoidance Camera'},
#      {'name': 'NAVCAM', 'full_name': 'Navigation Camera'},
#      {'name': 'PANCAM', 'full_name': 'Panoramic Camera'},
#      {'name': 'MINITES',
#       'full_name': 'Miniature Thermal Emission Spectrometer (Mini-TES)'},
#      {'name': 'ENTRY', 'full_name': 'Entry, Descent, and Landing Camera'},
#      {'name': 'RHAZ', 'full_name': 'Rear Hazard Avoidance Camera'}]}},
#   {'id': 156475,
#    'sol': 2010,
#    'camera': {'id': 17,
#     'name': 'PANCAM',
#     'rover_id': 6,
#     'full_name': 'Panoramic Camera'},
#    'img_src': 'http://mars.nasa.gov/mer/gallery/all/1/p/2010/1P306622804EFFA600P2410L2M1-BR.JPG',
#    'earth_date': '2009-09-20',
#    'rover': {'id': 6,
#     'name': 'Opportunity',
#     'landing_date': '2004-01-25',
#     'launch_date': '2003-07-07',
#     'status': 'complete',
#     'max_sol': 5111,
#     'max_date': '2018-06-11',
#     'total_photos': 198439,
#     'cameras': [{'name': 'FHAZ', 'full_name': 'Front Hazard Avoidance Camera'},
#      {'name': 'NAVCAM', 'full_name': 'Navigation Camera'},
#      {'name': 'PANCAM', 'full_name': 'Panoramic Camera'},
#      {'name': 'MINITES',
#       'full_name': 'Miniature Thermal Emission Spectrometer (Mini-TES)'},
#      {'name': 'ENTRY', 'full_name': 'Entry, Descent, and Landing Camera'},
#      {'name': 'RHAZ', 'full_name': 'Rear Hazard Avoidance Camera'}]}},
#   {'id': 156476,
#    'sol': 2010,
#    'camera': {'id': 17,
#     'name': 'PANCAM',
#     'rover_id': 6,
#     'full_name': 'Panoramic Camera'},
#    'img_src': 'http://mars.nasa.gov/mer/gallery/all/1/p/2010/1P306622804EFFA600P2410R2M1-BR.JPG',
#    'earth_date': '2009-09-20',
#    'rover': {'id': 6,
#     'name': 'Opportunity',
#     'landing_date': '2004-01-25',
#     'launch_date': '2003-07-07',
#     'status': 'complete',
#     'max_sol': 5111,
#     'max_date': '2018-06-11',
#     'total_photos': 198439,
#     'cameras': [{'name': 'FHAZ', 'full_name': 'Front Hazard Avoidance Camera'},
#      {'name': 'NAVCAM', 'full_name': 'Navigation Camera'},
#      {'name': 'PANCAM', 'full_name': 'Panoramic Camera'},
#      {'name': 'MINITES',
#       'full_name': 'Miniature Thermal Emission Spectrometer (Mini-TES)'},
#      {'name': 'ENTRY', 'full_name': 'Entry, Descent, and Landing Camera'},
#      {'name': 'RHAZ', 'full_name': 'Rear Hazard Avoidance Camera'}]}},
#   {'id': 156477,
#    'sol': 2010,
#    'camera': {'id': 17,
#     'name': 'PANCAM',
#     'rover_id': 6,
#     'full_name': 'Panoramic Camera'},
#    'img_src': 'http://mars.nasa.gov/mer/gallery/all/1/p/2010/1P306622894EFFA600P2410L5M1-BR.JPG',
#    'earth_date': '2009-09-20',
#    'rover': {'id': 6,
#     'name': 'Opportunity',
#     'landing_date': '2004-01-25',
#     'launch_date': '2003-07-07',
#     'status': 'complete',
#     'max_sol': 5111,
#     'max_date': '2018-06-11',
#     'total_photos': 198439,
#     'cameras': [{'name': 'FHAZ', 'full_name': 'Front Hazard Avoidance Camera'},
#      {'name': 'NAVCAM', 'full_name': 'Navigation Camera'},
#      {'name': 'PANCAM', 'full_name': 'Panoramic Camera'},
#      {'name': 'MINITES',
#       'full_name': 'Miniature Thermal Emission Spectrometer (Mini-TES)'},
#      {'name': 'ENTRY', 'full_name': 'Entry, Descent, and Landing Camera'},
#      {'name': 'RHAZ', 'full_name': 'Rear Hazard Avoidance Camera'}]}},
#   {'id': 156478,
#    'sol': 2010,
#    'camera': {'id': 17,
#     'name': 'PANCAM',
#     'rover_id': 6,
#     'full_name': 'Panoramic Camera'},
#    'img_src': 'http://mars.nasa.gov/mer/gallery/all/1/p/2010/1P306622970EFFA600P2410L7M1-BR.JPG',
#    'earth_date': '2009-09-20',
#    'rover': {'id': 6,
#     'name': 'Opportunity',
#     'landing_date': '2004-01-25',
#     'launch_date': '2003-07-07',
#     'status': 'complete',
#     'max_sol': 5111,
#     'max_date': '2018-06-11',
#     'total_photos': 198439,
#     'cameras': [{'name': 'FHAZ', 'full_name': 'Front Hazard Avoidance Camera'},
#      {'name': 'NAVCAM', 'full_name': 'Navigation Camera'},
#      {'name': 'PANCAM', 'full_name': 'Panoramic Camera'},
#      {'name': 'MINITES',
#       'full_name': 'Miniature Thermal Emission Spectrometer (Mini-TES)'},
#      {'name': 'ENTRY', 'full_name': 'Entry, Descent, and Landing Camera'},
#      {'name': 'RHAZ', 'full_name': 'Rear Hazard Avoidance Camera'}]}},
#   {'id': 156479,
#    'sol': 2010,
#    'camera': {'id': 17,
#     'name': 'PANCAM',
#     'rover_id': 6,
#     'full_name': 'Panoramic Camera'},
#    'img_src': 'http://mars.nasa.gov/mer/gallery/all/1/p/2010/1P306623129EFFA600P2410L2M1-BR.JPG',
#    'earth_date': '2009-09-20',
#    'rover': {'id': 6,
#     'name': 'Opportunity',
#     'landing_date': '2004-01-25',
#     'launch_date': '2003-07-07',
#     'status': 'complete',
#     'max_sol': 5111,
#     'max_date': '2018-06-11',
#     'total_photos': 198439,
#     'cameras': [{'name': 'FHAZ', 'full_name': 'Front Hazard Avoidance Camera'},
#      {'name': 'NAVCAM', 'full_name': 'Navigation Camera'},
#      {'name': 'PANCAM', 'full_name': 'Panoramic Camera'},
#      {'name': 'MINITES',
#       'full_name': 'Miniature Thermal Emission Spectrometer (Mini-TES)'},
#      {'name': 'ENTRY', 'full_name': 'Entry, Descent, and Landing Camera'},
#      {'name': 'RHAZ', 'full_name': 'Rear Hazard Avoidance Camera'}]}},
#   {'id': 156480,
#    'sol': 2010,
#    'camera': {'id': 17,
#     'name': 'PANCAM',
#     'rover_id': 6,
#     'full_name': 'Panoramic Camera'},
#    'img_src': 'http://mars.nasa.gov/mer/gallery/all/1/p/2010/1P306623129EFFA600P2410L2M2-BR.JPG',
#    'earth_date': '2009-09-20',
#    'rover': {'id': 6,
#     'name': 'Opportunity',
#     'landing_date': '2004-01-25',
#     'launch_date': '2003-07-07',
#     'status': 'complete',
#     'max_sol': 5111,
#     'max_date': '2018-06-11',
#     'total_photos': 198439,
#     'cameras': [{'name': 'FHAZ', 'full_name': 'Front Hazard Avoidance Camera'},
#      {'name': 'NAVCAM', 'full_name': 'Navigation Camera'},
#      {'name': 'PANCAM', 'full_name': 'Panoramic Camera'},
#      {'name': 'MINITES',
#       'full_name': 'Miniature Thermal Emission Spectrometer (Mini-TES)'},
#      {'name': 'ENTRY', 'full_name': 'Entry, Descent, and Landing Camera'},
#      {'name': 'RHAZ', 'full_name': 'Rear Hazard Avoidance Camera'}]}},
#   {'id': 156481,
#    'sol': 2010,
#    'camera': {'id': 17,
#     'name': 'PANCAM',
#     'rover_id': 6,
#     'full_name': 'Panoramic Camera'},
#    'img_src': 'http://mars.nasa.gov/mer/gallery/all/1/p/2010/1P306623129EFFA600P2410L2M3-BR.JPG',
#    'earth_date': '2009-09-20',
#    'rover': {'id': 6,
#     'name': 'Opportunity',
#     'landing_date': '2004-01-25',
#     'launch_date': '2003-07-07',
#     'status': 'complete',
#     'max_sol': 5111,
#     'max_date': '2018-06-11',
#     'total_photos': 198439,
#     'cameras': [{'name': 'FHAZ', 'full_name': 'Front Hazard Avoidance Camera'},
#      {'name': 'NAVCAM', 'full_name': 'Navigation Camera'},
#      {'name': 'PANCAM', 'full_name': 'Panoramic Camera'},
#      {'name': 'MINITES',
#       'full_name': 'Miniature Thermal Emission Spectrometer (Mini-TES)'},
#      {'name': 'ENTRY', 'full_name': 'Entry, Descent, and Landing Camera'},
#      {'name': 'RHAZ', 'full_name': 'Rear Hazard Avoidance Camera'}]}},
#   {'id': 156482,
#    'sol': 2010,
#    'camera': {'id': 17,
#     'name': 'PANCAM',
#     'rover_id': 6,
#     'full_name': 'Panoramic Camera'},
#    'img_src': 'http://mars.nasa.gov/mer/gallery/all/1/p/2010/1P306623129EFFA600P2410L2M4-BR.JPG',
#    'earth_date': '2009-09-20',
#    'rover': {'id': 6,
#     'name': 'Opportunity',
#     'landing_date': '2004-01-25',
#     'launch_date': '2003-07-07',
#     'status': 'complete',
#     'max_sol': 5111,
#     'max_date': '2018-06-11',
#     'total_photos': 198439,
#     'cameras': [{'name': 'FHAZ', 'full_name': 'Front Hazard Avoidance Camera'},
#      {'name': 'NAVCAM', 'full_name': 'Navigation Camera'},
#      {'name': 'PANCAM', 'full_name': 'Panoramic Camera'},
#      {'name': 'MINITES',
#       'full_name': 'Miniature Thermal Emission Spectrometer (Mini-TES)'},
#      {'name': 'ENTRY', 'full_name': 'Entry, Descent, and Landing Camera'},
#      {'name': 'RHAZ', 'full_name': 'Rear Hazard Avoidance Camera'}]}},
#   {'id': 156483,
#    'sol': 2010,
#    'camera': {'id': 17,
#     'name': 'PANCAM',
#     'rover_id': 6,
#     'full_name': 'Panoramic Camera'},
#    'img_src': 'http://mars.nasa.gov/mer/gallery/all/1/p/2010/1P306623129EFFA600P2410R2M1-BR.JPG',
#    'earth_date': '2009-09-20',
#    'rover': {'id': 6,
#     'name': 'Opportunity',
#     'landing_date': '2004-01-25',
#     'launch_date': '2003-07-07',
#     'status': 'complete',
#     'max_sol': 5111,
#     'max_date': '2018-06-11',
#     'total_photos': 198439,
#     'cameras': [{'name': 'FHAZ', 'full_name': 'Front Hazard Avoidance Camera'},
#      {'name': 'NAVCAM', 'full_name': 'Navigation Camera'},
#      {'name': 'PANCAM', 'full_name': 'Panoramic Camera'},
#      {'name': 'MINITES',
#       'full_name': 'Miniature Thermal Emission Spectrometer (Mini-TES)'},
#      {'name': 'ENTRY', 'full_name': 'Entry, Descent, and Landing Camera'},
#      {'name': 'RHAZ', 'full_name': 'Rear Hazard Avoidance Camera'}]}},
#   {'id': 156484,
#    'sol': 2010,
#    'camera': {'id': 17,
#     'name': 'PANCAM',
#     'rover_id': 6,
#     'full_name': 'Panoramic Camera'},
#    'img_src': 'http://mars.nasa.gov/mer/gallery/all/1/p/2010/1P306623129EFFA600P2410R2M2-BR.JPG',
#    'earth_date': '2009-09-20',
#    'rover': {'id': 6,
#     'name': 'Opportunity',
#     'landing_date': '2004-01-25',
#     'launch_date': '2003-07-07',
#     'status': 'complete',
#     'max_sol': 5111,
#     'max_date': '2018-06-11',
#     'total_photos': 198439,
#     'cameras': [{'name': 'FHAZ', 'full_name': 'Front Hazard Avoidance Camera'},
#      {'name': 'NAVCAM', 'full_name': 'Navigation Camera'},
#      {'name': 'PANCAM', 'full_name': 'Panoramic Camera'},
#      {'name': 'MINITES',
#       'full_name': 'Miniature Thermal Emission Spectrometer (Mini-TES)'},
#      {'name': 'ENTRY', 'full_name': 'Entry, Descent, and Landing Camera'},
#      {'name': 'RHAZ', 'full_name': 'Rear Hazard Avoidance Camera'}]}},
#   {'id': 156485,
#    'sol': 2010,
#    'camera': {'id': 17,
#     'name': 'PANCAM',
#     'rover_id': 6,
#     'full_name': 'Panoramic Camera'},
#    'img_src': 'http://mars.nasa.gov/mer/gallery/all/1/p/2010/1P306623218EFFA600P2410L5M1-BR.JPG',
#    'earth_date': '2009-09-20',
#    'rover': {'id': 6,
#     'name': 'Opportunity',
#     'landing_date': '2004-01-25',
#     'launch_date': '2003-07-07',
#     'status': 'complete',
#     'max_sol': 5111,
#     'max_date': '2018-06-11',
#     'total_photos': 198439,
#     'cameras': [{'name': 'FHAZ', 'full_name': 'Front Hazard Avoidance Camera'},
#      {'name': 'NAVCAM', 'full_name': 'Navigation Camera'},
#      {'name': 'PANCAM', 'full_name': 'Panoramic Camera'},
#      {'name': 'MINITES',
#       'full_name': 'Miniature Thermal Emission Spectrometer (Mini-TES)'},
#      {'name': 'ENTRY', 'full_name': 'Entry, Descent, and Landing Camera'},
#      {'name': 'RHAZ', 'full_name': 'Rear Hazard Avoidance Camera'}]}},
#   {'id': 156486,
#    'sol': 2010,
#    'camera': {'id': 17,
#     'name': 'PANCAM',
#     'rover_id': 6,
#     'full_name': 'Panoramic Camera'},
#    'img_src': 'http://mars.nasa.gov/mer/gallery/all/1/p/2010/1P306623297EFFA600P2410L7M1-BR.JPG',
#    'earth_date': '2009-09-20',
#    'rover': {'id': 6,
#     'name': 'Opportunity',
#     'landing_date': '2004-01-25',
#     'launch_date': '2003-07-07',
#     'status': 'complete',
#     'max_sol': 5111,
#     'max_date': '2018-06-11',
#     'total_photos': 198439,
#     'cameras': [{'name': 'FHAZ', 'full_name': 'Front Hazard Avoidance Camera'},
#      {'name': 'NAVCAM', 'full_name': 'Navigation Camera'},
#      {'name': 'PANCAM', 'full_name': 'Panoramic Camera'},
#      {'name': 'MINITES',
#       'full_name': 'Miniature Thermal Emission Spectrometer (Mini-TES)'},
#      {'name': 'ENTRY', 'full_name': 'Entry, Descent, and Landing Camera'},
#      {'name': 'RHAZ', 'full_name': 'Rear Hazard Avoidance Camera'}]}},
#   {'id': 156487,
#    'sol': 2010,
#    'camera': {'id': 17,
#     'name': 'PANCAM',
#     'rover_id': 6,
#     'full_name': 'Panoramic Camera'},
#    'img_src': 'http://mars.nasa.gov/mer/gallery/all/1/p/2010/1P306623470EFFA600P2410L2M1-BR.JPG',
#    'earth_date': '2009-09-20',
#    'rover': {'id': 6,
#     'name': 'Opportunity',
#     'landing_date': '2004-01-25',
#     'launch_date': '2003-07-07',
#     'status': 'complete',
#     'max_sol': 5111,
#     'max_date': '2018-06-11',
#     'total_photos': 198439,
#     'cameras': [{'name': 'FHAZ', 'full_name': 'Front Hazard Avoidance Camera'},
#      {'name': 'NAVCAM', 'full_name': 'Navigation Camera'},
#      {'name': 'PANCAM', 'full_name': 'Panoramic Camera'},
#      {'name': 'MINITES',
#       'full_name': 'Miniature Thermal Emission Spectrometer (Mini-TES)'},
#      {'name': 'ENTRY', 'full_name': 'Entry, Descent, and Landing Camera'},
#      {'name': 'RHAZ', 'full_name': 'Rear Hazard Avoidance Camera'}]}},
#   {'id': 156488,
#    'sol': 2010,
#    'camera': {'id': 17,
#     'name': 'PANCAM',
#     'rover_id': 6,
#     'full_name': 'Panoramic Camera'},
#    'img_src': 'http://mars.nasa.gov/mer/gallery/all/1/p/2010/1P306623470EFFA600P2410R2M1-BR.JPG',
#    'earth_date': '2009-09-20',
#    'rover': {'id': 6,
#     'name': 'Opportunity',
#     'landing_date': '2004-01-25',
#     'launch_date': '2003-07-07',
#     'status': 'complete',
#     'max_sol': 5111,
#     'max_date': '2018-06-11',
#     'total_photos': 198439,
#     'cameras': [{'name': 'FHAZ', 'full_name': 'Front Hazard Avoidance Camera'},
#      {'name': 'NAVCAM', 'full_name': 'Navigation Camera'},
#      {'name': 'PANCAM', 'full_name': 'Panoramic Camera'},
#      {'name': 'MINITES',
#       'full_name': 'Miniature Thermal Emission Spectrometer (Mini-TES)'},
#      {'name': 'ENTRY', 'full_name': 'Entry, Descent, and Landing Camera'},
#      {'name': 'RHAZ', 'full_name': 'Rear Hazard Avoidance Camera'}]}},
#   {'id': 156489,
#    'sol': 2010,
#    'camera': {'id': 17,
#     'name': 'PANCAM',
#     'rover_id': 6,
#     'full_name': 'Panoramic Camera'},
#    'img_src': 'http://mars.nasa.gov/mer/gallery/all/1/p/2010/1P306623545EFFA600P2410L5M1-BR.JPG',
#    'earth_date': '2009-09-20',
#    'rover': {'id': 6,
#     'name': 'Opportunity',
#     'landing_date': '2004-01-25',
#     'launch_date': '2003-07-07',
#     'status': 'complete',
#     'max_sol': 5111,
#     'max_date': '2018-06-11',
#     'total_photos': 198439,
#     'cameras': [{'name': 'FHAZ', 'full_name': 'Front Hazard Avoidance Camera'},
#      {'name': 'NAVCAM', 'full_name': 'Navigation Camera'},
#      {'name': 'PANCAM', 'full_name': 'Panoramic Camera'},
#      {'name': 'MINITES',
#       'full_name': 'Miniature Thermal Emission Spectrometer (Mini-TES)'},
#      {'name': 'ENTRY', 'full_name': 'Entry, Descent, and Landing Camera'},
#      {'name': 'RHAZ', 'full_name': 'Rear Hazard Avoidance Camera'}]}},
#   {'id': 156490,
#    'sol': 2010,
#    'camera': {'id': 17,
#     'name': 'PANCAM',
#     'rover_id': 6,
#     'full_name': 'Panoramic Camera'},
#    'img_src': 'http://mars.nasa.gov/mer/gallery/all/1/p/2010/1P306623545EFFA600P2410L5M2-BR.JPG',
#    'earth_date': '2009-09-20',
#    'rover': {'id': 6,
#     'name': 'Opportunity',
#     'landing_date': '2004-01-25',
#     'launch_date': '2003-07-07',
#     'status': 'complete',
#     'max_sol': 5111,
#     'max_date': '2018-06-11',
#     'total_photos': 198439,
#     'cameras': [{'name': 'FHAZ', 'full_name': 'Front Hazard Avoidance Camera'},
#      {'name': 'NAVCAM', 'full_name': 'Navigation Camera'},
#      {'name': 'PANCAM', 'full_name': 'Panoramic Camera'},
#      {'name': 'MINITES',
#       'full_name': 'Miniature Thermal Emission Spectrometer (Mini-TES)'},
#      {'name': 'ENTRY', 'full_name': 'Entry, Descent, and Landing Camera'},
#      {'name': 'RHAZ', 'full_name': 'Rear Hazard Avoidance Camera'}]}},
#   {'id': 156491,
#    'sol': 2010,
#    'camera': {'id': 17,
#     'name': 'PANCAM',
#     'rover_id': 6,
#     'full_name': 'Panoramic Camera'},
#    'img_src': 'http://mars.nasa.gov/mer/gallery/all/1/p/2010/1P306623545EFFA600P2410L5M3-BR.JPG',
#    'earth_date': '2009-09-20',
#    'rover': {'id': 6,
#     'name': 'Opportunity',
#     'landing_date': '2004-01-25',
#     'launch_date': '2003-07-07',
#     'status': 'complete',
#     'max_sol': 5111,
#     'max_date': '2018-06-11',
#     'total_photos': 198439,
#     'cameras': [{'name': 'FHAZ', 'full_name': 'Front Hazard Avoidance Camera'},
#      {'name': 'NAVCAM', 'full_name': 'Navigation Camera'},
#      {'name': 'PANCAM', 'full_name': 'Panoramic Camera'},
#      {'name': 'MINITES',
#       'full_name': 'Miniature Thermal Emission Spectrometer (Mini-TES)'},
#      {'name': 'ENTRY', 'full_name': 'Entry, Descent, and Landing Camera'},
#      {'name': 'RHAZ', 'full_name': 'Rear Hazard Avoidance Camera'}]}},
#   {'id': 156492,
#    'sol': 2010,
#    'camera': {'id': 17,
#     'name': 'PANCAM',
#     'rover_id': 6,
#     'full_name': 'Panoramic Camera'},
#    'img_src': 'http://mars.nasa.gov/mer/gallery/all/1/p/2010/1P306623621EFFA600P2410L7M1-BR.JPG',
#    'earth_date': '2009-09-20',
#    'rover': {'id': 6,
#     'name': 'Opportunity',
#     'landing_date': '2004-01-25',
#     'launch_date': '2003-07-07',
#     'status': 'complete',
#     'max_sol': 5111,
#     'max_date': '2018-06-11',
#     'total_photos': 198439,
#     'cameras': [{'name': 'FHAZ', 'full_name': 'Front Hazard Avoidance Camera'},
#      {'name': 'NAVCAM', 'full_name': 'Navigation Camera'},
#      {'name': 'PANCAM', 'full_name': 'Panoramic Camera'},
#      {'name': 'MINITES',
#       'full_name': 'Miniature Thermal Emission Spectrometer (Mini-TES)'},
#      {'name': 'ENTRY', 'full_name': 'Entry, Descent, and Landing Camera'},
#      {'name': 'RHAZ', 'full_name': 'Rear Hazard Avoidance Camera'}]}},
#   {'id': 156493,
#    'sol': 2010,
#    'camera': {'id': 17,
#     'name': 'PANCAM',
#     'rover_id': 6,
#     'full_name': 'Panoramic Camera'},
#    'img_src': 'http://mars.nasa.gov/mer/gallery/all/1/p/2010/1P306623780EFFA600P2410L2M1-BR.JPG',
#    'earth_date': '2009-09-20',
#    'rover': {'id': 6,
#     'name': 'Opportunity',
#     'landing_date': '2004-01-25',
#     'launch_date': '2003-07-07',
#     'status': 'complete',
#     'max_sol': 5111,
#     'max_date': '2018-06-11',
#     'total_photos': 198439,
#     'cameras': [{'name': 'FHAZ', 'full_name': 'Front Hazard Avoidance Camera'},
#      {'name': 'NAVCAM', 'full_name': 'Navigation Camera'},
# ...
#       'full_name': 'Miniature Thermal Emission Spectrometer (Mini-TES)'},
#      {'name': 'ENTRY', 'full_name': 'Entry, Descent, and Landing Camera'},
#      {'name': 'RHAZ', 'full_name': 'Rear Hazard Avoidance Camera'}]}},
#   {'id': 156524,
#    'sol': 2010,
#    'camera': {'id': 17,
#     'name': 'PANCAM',
#     'rover_id': 6,
#     'full_name': 'Panoramic Camera'},
#    'img_src': 'http://mars.nasa.gov/mer/gallery/all/1/p/2010/1P306625978EFFA600P2410L7M1-BR.JPG',
#    'earth_date': '2009-09-20',
#    'rover': {'id': 6,
#     'name': 'Opportunity',
#     'landing_date': '2004-01-25',
#     'launch_date': '2003-07-07',
#     'status': 'complete',
#     'max_sol': 5111,
#     'max_date': '2018-06-11',
#     'total_photos': 198439,
#     'cameras': [{'name': 'FHAZ', 'full_name': 'Front Hazard Avoidance Camera'},
#      {'name': 'NAVCAM', 'full_name': 'Navigation Camera'},
#      {'name': 'PANCAM', 'full_name': 'Panoramic Camera'},
#      {'name': 'MINITES',
#       'full_name': 'Miniature Thermal Emission Spectrometer (Mini-TES)'},
#      {'name': 'ENTRY', 'full_name': 'Entry, Descent, and Landing Camera'},
#      {'name': 'RHAZ', 'full_name': 'Rear Hazard Avoidance Camera'}]}},
#   {'id': 156525,
#    'sol': 2010,
#    'camera': {'id': 17,
#     'name': 'PANCAM',
#     'rover_id': 6,
#     'full_name': 'Panoramic Camera'},
#    'img_src': 'http://mars.nasa.gov/mer/gallery/all/1/p/2010/1P306626158EFFA600P2410L2M1-BR.JPG',
#    'earth_date': '2009-09-20',
#    'rover': {'id': 6,
#     'name': 'Opportunity',
#     'landing_date': '2004-01-25',
#     'launch_date': '2003-07-07',
#     'status': 'complete',
#     'max_sol': 5111,
#     'max_date': '2018-06-11',
#     'total_photos': 198439,
#     'cameras': [{'name': 'FHAZ', 'full_name': 'Front Hazard Avoidance Camera'},
#      {'name': 'NAVCAM', 'full_name': 'Navigation Camera'},
#      {'name': 'PANCAM', 'full_name': 'Panoramic Camera'},
#      {'name': 'MINITES',
#       'full_name': 'Miniature Thermal Emission Spectrometer (Mini-TES)'},
#      {'name': 'ENTRY', 'full_name': 'Entry, Descent, and Landing Camera'},
#      {'name': 'RHAZ', 'full_name': 'Rear Hazard Avoidance Camera'}]}},
#   {'id': 156526,
#    'sol': 2010,
#    'camera': {'id': 17,
#     'name': 'PANCAM',
#     'rover_id': 6,
#     'full_name': 'Panoramic Camera'},
#    'img_src': 'http://mars.nasa.gov/mer/gallery/all/1/p/2010/1P306626158EFFA600P2410R2M1-BR.JPG',
#    'earth_date': '2009-09-20',
#    'rover': {'id': 6,
#     'name': 'Opportunity',
#     'landing_date': '2004-01-25',
#     'launch_date': '2003-07-07',
#     'status': 'complete',
#     'max_sol': 5111,
#     'max_date': '2018-06-11',
#     'total_photos': 198439,
#     'cameras': [{'name': 'FHAZ', 'full_name': 'Front Hazard Avoidance Camera'},
#      {'name': 'NAVCAM', 'full_name': 'Navigation Camera'},
#      {'name': 'PANCAM', 'full_name': 'Panoramic Camera'},
#      {'name': 'MINITES',
#       'full_name': 'Miniature Thermal Emission Spectrometer (Mini-TES)'},
#      {'name': 'ENTRY', 'full_name': 'Entry, Descent, and Landing Camera'},
#      {'name': 'RHAZ', 'full_name': 'Rear Hazard Avoidance Camera'}]}},
#   {'id': 156527,
#    'sol': 2010,
#    'camera': {'id': 17,
#     'name': 'PANCAM',
#     'rover_id': 6,
#     'full_name': 'Panoramic Camera'},
#    'img_src': 'http://mars.nasa.gov/mer/gallery/all/1/p/2010/1P306626242EFFA600P2410L5M1-BR.JPG',
#    'earth_date': '2009-09-20',
#    'rover': {'id': 6,
#     'name': 'Opportunity',
#     'landing_date': '2004-01-25',
#     'launch_date': '2003-07-07',
#     'status': 'complete',
#     'max_sol': 5111,
#     'max_date': '2018-06-11',
#     'total_photos': 198439,
#     'cameras': [{'name': 'FHAZ', 'full_name': 'Front Hazard Avoidance Camera'},
#      {'name': 'NAVCAM', 'full_name': 'Navigation Camera'},
#      {'name': 'PANCAM', 'full_name': 'Panoramic Camera'},
#      {'name': 'MINITES',
#       'full_name': 'Miniature Thermal Emission Spectrometer (Mini-TES)'},
#      {'name': 'ENTRY', 'full_name': 'Entry, Descent, and Landing Camera'},
#      {'name': 'RHAZ', 'full_name': 'Rear Hazard Avoidance Camera'}]}},
#   {'id': 156528,
#    'sol': 2010,
#    'camera': {'id': 17,
#     'name': 'PANCAM',
#     'rover_id': 6,
#     'full_name': 'Panoramic Camera'},
#    'img_src': 'http://mars.nasa.gov/mer/gallery/all/1/p/2010/1P306626322EFFA600P2410L7M1-BR.JPG',
#    'earth_date': '2009-09-20',
#    'rover': {'id': 6,
#     'name': 'Opportunity',
#     'landing_date': '2004-01-25',
#     'launch_date': '2003-07-07',
#     'status': 'complete',
#     'max_sol': 5111,
#     'max_date': '2018-06-11',
#     'total_photos': 198439,
#     'cameras': [{'name': 'FHAZ', 'full_name': 'Front Hazard Avoidance Camera'},
#      {'name': 'NAVCAM', 'full_name': 'Navigation Camera'},
#      {'name': 'PANCAM', 'full_name': 'Panoramic Camera'},
#      {'name': 'MINITES',
#       'full_name': 'Miniature Thermal Emission Spectrometer (Mini-TES)'},
#      {'name': 'ENTRY', 'full_name': 'Entry, Descent, and Landing Camera'},
#      {'name': 'RHAZ', 'full_name': 'Rear Hazard Avoidance Camera'}]}},
#   {'id': 156529,
#    'sol': 2010,
#    'camera': {'id': 17,
#     'name': 'PANCAM',
#     'rover_id': 6,
#     'full_name': 'Panoramic Camera'},
#    'img_src': 'http://mars.nasa.gov/mer/gallery/all/1/p/2010/1P306626487EFFA600P2410L2M1-BR.JPG',
#    'earth_date': '2009-09-20',
#    'rover': {'id': 6,
#     'name': 'Opportunity',
#     'landing_date': '2004-01-25',
#     'launch_date': '2003-07-07',
#     'status': 'complete',
#     'max_sol': 5111,
#     'max_date': '2018-06-11',
#     'total_photos': 198439,
#     'cameras': [{'name': 'FHAZ', 'full_name': 'Front Hazard Avoidance Camera'},
#      {'name': 'NAVCAM', 'full_name': 'Navigation Camera'},
#      {'name': 'PANCAM', 'full_name': 'Panoramic Camera'},
#      {'name': 'MINITES',
#       'full_name': 'Miniature Thermal Emission Spectrometer (Mini-TES)'},
#      {'name': 'ENTRY', 'full_name': 'Entry, Descent, and Landing Camera'},
#      {'name': 'RHAZ', 'full_name': 'Rear Hazard Avoidance Camera'}]}},
#   {'id': 156530,
#    'sol': 2010,
#    'camera': {'id': 17,
#     'name': 'PANCAM',
#     'rover_id': 6,
#     'full_name': 'Panoramic Camera'},
#    'img_src': 'http://mars.nasa.gov/mer/gallery/all/1/p/2010/1P306626487EFFA600P2410R2M1-BR.JPG',
#    'earth_date': '2009-09-20',
#    'rover': {'id': 6,
#     'name': 'Opportunity',
#     'landing_date': '2004-01-25',
#     'launch_date': '2003-07-07',
#     'status': 'complete',
#     'max_sol': 5111,
#     'max_date': '2018-06-11',
#     'total_photos': 198439,
#     'cameras': [{'name': 'FHAZ', 'full_name': 'Front Hazard Avoidance Camera'},
#      {'name': 'NAVCAM', 'full_name': 'Navigation Camera'},
#      {'name': 'PANCAM', 'full_name': 'Panoramic Camera'},
#      {'name': 'MINITES',
#       'full_name': 'Miniature Thermal Emission Spectrometer (Mini-TES)'},
#      {'name': 'ENTRY', 'full_name': 'Entry, Descent, and Landing Camera'},
#      {'name': 'RHAZ', 'full_name': 'Rear Hazard Avoidance Camera'}]}},
#   {'id': 156531,
#    'sol': 2010,
#    'camera': {'id': 17,
#     'name': 'PANCAM',
#     'rover_id': 6,
#     'full_name': 'Panoramic Camera'},
#    'img_src': 'http://mars.nasa.gov/mer/gallery/all/1/p/2010/1P306626579EFFA600P2410L5M1-BR.JPG',
#    'earth_date': '2009-09-20',
#    'rover': {'id': 6,
#     'name': 'Opportunity',
#     'landing_date': '2004-01-25',
#     'launch_date': '2003-07-07',
#     'status': 'complete',
#     'max_sol': 5111,
#     'max_date': '2018-06-11',
#     'total_photos': 198439,
#     'cameras': [{'name': 'FHAZ', 'full_name': 'Front Hazard Avoidance Camera'},
#      {'name': 'NAVCAM', 'full_name': 'Navigation Camera'},
#      {'name': 'PANCAM', 'full_name': 'Panoramic Camera'},
#      {'name': 'MINITES',
#       'full_name': 'Miniature Thermal Emission Spectrometer (Mini-TES)'},
#      {'name': 'ENTRY', 'full_name': 'Entry, Descent, and Landing Camera'},
#      {'name': 'RHAZ', 'full_name': 'Rear Hazard Avoidance Camera'}]}},
#   {'id': 156532,
#    'sol': 2010,
#    'camera': {'id': 17,
#     'name': 'PANCAM',
#     'rover_id': 6,
#     'full_name': 'Panoramic Camera'},
#    'img_src': 'http://mars.nasa.gov/mer/gallery/all/1/p/2010/1P306626652EFFA600P2410L7M1-BR.JPG',
#    'earth_date': '2009-09-20',
#    'rover': {'id': 6,
#     'name': 'Opportunity',
#     'landing_date': '2004-01-25',
#     'launch_date': '2003-07-07',
#     'status': 'complete',
#     'max_sol': 5111,
#     'max_date': '2018-06-11',
#     'total_photos': 198439,
#     'cameras': [{'name': 'FHAZ', 'full_name': 'Front Hazard Avoidance Camera'},
#      {'name': 'NAVCAM', 'full_name': 'Navigation Camera'},
#      {'name': 'PANCAM', 'full_name': 'Panoramic Camera'},
#      {'name': 'MINITES',
#       'full_name': 'Miniature Thermal Emission Spectrometer (Mini-TES)'},
#      {'name': 'ENTRY', 'full_name': 'Entry, Descent, and Landing Camera'},
#      {'name': 'RHAZ', 'full_name': 'Rear Hazard Avoidance Camera'}]}},
#   {'id': 156533,
#    'sol': 2010,
#    'camera': {'id': 17,
#     'name': 'PANCAM',
#     'rover_id': 6,
#     'full_name': 'Panoramic Camera'},
#    'img_src': 'http://mars.nasa.gov/mer/gallery/all/1/p/2010/1P306626812EFFA600P2410L2M1-BR.JPG',
#    'earth_date': '2009-09-20',
#    'rover': {'id': 6,
#     'name': 'Opportunity',
#     'landing_date': '2004-01-25',
#     'launch_date': '2003-07-07',
#     'status': 'complete',
#     'max_sol': 5111,
#     'max_date': '2018-06-11',
#     'total_photos': 198439,
#     'cameras': [{'name': 'FHAZ', 'full_name': 'Front Hazard Avoidance Camera'},
#      {'name': 'NAVCAM', 'full_name': 'Navigation Camera'},
#      {'name': 'PANCAM', 'full_name': 'Panoramic Camera'},
#      {'name': 'MINITES',
#       'full_name': 'Miniature Thermal Emission Spectrometer (Mini-TES)'},
#      {'name': 'ENTRY', 'full_name': 'Entry, Descent, and Landing Camera'},
#      {'name': 'RHAZ', 'full_name': 'Rear Hazard Avoidance Camera'}]}},
#   {'id': 156534,
#    'sol': 2010,
#    'camera': {'id': 17,
#     'name': 'PANCAM',
#     'rover_id': 6,
#     'full_name': 'Panoramic Camera'},
#    'img_src': 'http://mars.nasa.gov/mer/gallery/all/1/p/2010/1P306626812EFFA600P2410R2M1-BR.JPG',
#    'earth_date': '2009-09-20',
#    'rover': {'id': 6,
#     'name': 'Opportunity',
#     'landing_date': '2004-01-25',
#     'launch_date': '2003-07-07',
#     'status': 'complete',
#     'max_sol': 5111,
#     'max_date': '2018-06-11',
#     'total_photos': 198439,
#     'cameras': [{'name': 'FHAZ', 'full_name': 'Front Hazard Avoidance Camera'},
#      {'name': 'NAVCAM', 'full_name': 'Navigation Camera'},
#      {'name': 'PANCAM', 'full_name': 'Panoramic Camera'},
#      {'name': 'MINITES',
#       'full_name': 'Miniature Thermal Emission Spectrometer (Mini-TES)'},
#      {'name': 'ENTRY', 'full_name': 'Entry, Descent, and Landing Camera'},
#      {'name': 'RHAZ', 'full_name': 'Rear Hazard Avoidance Camera'}]}},
#   {'id': 156535,
#    'sol': 2010,
#    'camera': {'id': 17,
#     'name': 'PANCAM',
#     'rover_id': 6,
#     'full_name': 'Panoramic Camera'},
#    'img_src': 'http://mars.nasa.gov/mer/gallery/all/1/p/2010/1P306626902EFFA600P2410L5M1-BR.JPG',
#    'earth_date': '2009-09-20',
#    'rover': {'id': 6,
#     'name': 'Opportunity',
#     'landing_date': '2004-01-25',
#     'launch_date': '2003-07-07',
#     'status': 'complete',
#     'max_sol': 5111,
#     'max_date': '2018-06-11',
#     'total_photos': 198439,
#     'cameras': [{'name': 'FHAZ', 'full_name': 'Front Hazard Avoidance Camera'},
#      {'name': 'NAVCAM', 'full_name': 'Navigation Camera'},
#      {'name': 'PANCAM', 'full_name': 'Panoramic Camera'},
#      {'name': 'MINITES',
#       'full_name': 'Miniature Thermal Emission Spectrometer (Mini-TES)'},
#      {'name': 'ENTRY', 'full_name': 'Entry, Descent, and Landing Camera'},
#      {'name': 'RHAZ', 'full_name': 'Rear Hazard Avoidance Camera'}]}},
#   {'id': 156536,
#    'sol': 2010,
#    'camera': {'id': 17,
#     'name': 'PANCAM',
#     'rover_id': 6,
#     'full_name': 'Panoramic Camera'},
#    'img_src': 'http://mars.nasa.gov/mer/gallery/all/1/p/2010/1P306626976EFFA600P2410L7M1-BR.JPG',
#    'earth_date': '2009-09-20',
#    'rover': {'id': 6,
#     'name': 'Opportunity',
#     'landing_date': '2004-01-25',
#     'launch_date': '2003-07-07',
#     'status': 'complete',
#     'max_sol': 5111,
#     'max_date': '2018-06-11',
#     'total_photos': 198439,
#     'cameras': [{'name': 'FHAZ', 'full_name': 'Front Hazard Avoidance Camera'},
#      {'name': 'NAVCAM', 'full_name': 'Navigation Camera'},
#      {'name': 'PANCAM', 'full_name': 'Panoramic Camera'},
#      {'name': 'MINITES',
#       'full_name': 'Miniature Thermal Emission Spectrometer (Mini-TES)'},
#      {'name': 'ENTRY', 'full_name': 'Entry, Descent, and Landing Camera'},
#      {'name': 'RHAZ', 'full_name': 'Rear Hazard Avoidance Camera'}]}},
#   {'id': 156537,
#    'sol': 2010,
#    'camera': {'id': 17,
#     'name': 'PANCAM',
#     'rover_id': 6,
#     'full_name': 'Panoramic Camera'},
#    'img_src': 'http://mars.nasa.gov/mer/gallery/all/1/p/2010/1P306627153EFFA600P2410L2M1-BR.JPG',
#    'earth_date': '2009-09-20',
#    'rover': {'id': 6,
#     'name': 'Opportunity',
#     'landing_date': '2004-01-25',
#     'launch_date': '2003-07-07',
#     'status': 'complete',
#     'max_sol': 5111,
#     'max_date': '2018-06-11',
#     'total_photos': 198439,
#     'cameras': [{'name': 'FHAZ', 'full_name': 'Front Hazard Avoidance Camera'},
#      {'name': 'NAVCAM', 'full_name': 'Navigation Camera'},
#      {'name': 'PANCAM', 'full_name': 'Panoramic Camera'},
#      {'name': 'MINITES',
#       'full_name': 'Miniature Thermal Emission Spectrometer (Mini-TES)'},
#      {'name': 'ENTRY', 'full_name': 'Entry, Descent, and Landing Camera'},
#      {'name': 'RHAZ', 'full_name': 'Rear Hazard Avoidance Camera'}]}},
#   {'id': 156538,
#    'sol': 2010,
#    'camera': {'id': 17,
#     'name': 'PANCAM',
#     'rover_id': 6,
#     'full_name': 'Panoramic Camera'},
#    'img_src': 'http://mars.nasa.gov/mer/gallery/all/1/p/2010/1P306627153EFFA600P2410R2M1-BR.JPG',
#    'earth_date': '2009-09-20',
#    'rover': {'id': 6,
#     'name': 'Opportunity',
#     'landing_date': '2004-01-25',
#     'launch_date': '2003-07-07',
#     'status': 'complete',
#     'max_sol': 5111,
#     'max_date': '2018-06-11',
#     'total_photos': 198439,
#     'cameras': [{'name': 'FHAZ', 'full_name': 'Front Hazard Avoidance Camera'},
#      {'name': 'NAVCAM', 'full_name': 'Navigation Camera'},
#      {'name': 'PANCAM', 'full_name': 'Panoramic Camera'},
#      {'name': 'MINITES',
#       'full_name': 'Miniature Thermal Emission Spectrometer (Mini-TES)'},
#      {'name': 'ENTRY', 'full_name': 'Entry, Descent, and Landing Camera'},
#      {'name': 'RHAZ', 'full_name': 'Rear Hazard Avoidance Camera'}]}},
#   {'id': 156539,
#    'sol': 2010,
#    'camera': {'id': 17,
#     'name': 'PANCAM',
#     'rover_id': 6,
#     'full_name': 'Panoramic Camera'},
#    'img_src': 'http://mars.nasa.gov/mer/gallery/all/1/p/2010/1P306627230EFFA600P2410L5M1-BR.JPG',
#    'earth_date': '2009-09-20',
#    'rover': {'id': 6,
#     'name': 'Opportunity',
#     'landing_date': '2004-01-25',
#     'launch_date': '2003-07-07',
#     'status': 'complete',
#     'max_sol': 5111,
#     'max_date': '2018-06-11',
#     'total_photos': 198439,
#     'cameras': [{'name': 'FHAZ', 'full_name': 'Front Hazard Avoidance Camera'},
#      {'name': 'NAVCAM', 'full_name': 'Navigation Camera'},
#      {'name': 'PANCAM', 'full_name': 'Panoramic Camera'},
#      {'name': 'MINITES',
#       'full_name': 'Miniature Thermal Emission Spectrometer (Mini-TES)'},
#      {'name': 'ENTRY', 'full_name': 'Entry, Descent, and Landing Camera'},
#      {'name': 'RHAZ', 'full_name': 'Rear Hazard Avoidance Camera'}]}},
#   {'id': 156540,
#    'sol': 2010,
#    'camera': {'id': 17,
#     'name': 'PANCAM',
#     'rover_id': 6,
#     'full_name': 'Panoramic Camera'},
#    'img_src': 'http://mars.nasa.gov/mer/gallery/all/1/p/2010/1P306627312EFFA600P2410L7M1-BR.JPG',
#    'earth_date': '2009-09-20',
#    'rover': {'id': 6,
#     'name': 'Opportunity',
#     'landing_date': '2004-01-25',
#     'launch_date': '2003-07-07',
#     'status': 'complete',
#     'max_sol': 5111,
#     'max_date': '2018-06-11',
#     'total_photos': 198439,
#     'cameras': [{'name': 'FHAZ', 'full_name': 'Front Hazard Avoidance Camera'},
#      {'name': 'NAVCAM', 'full_name': 'Navigation Camera'},
#      {'name': 'PANCAM', 'full_name': 'Panoramic Camera'},
#      {'name': 'MINITES',
#       'full_name': 'Miniature Thermal Emission Spectrometer (Mini-TES)'},
#      {'name': 'ENTRY', 'full_name': 'Entry, Descent, and Landing Camera'},
#      {'name': 'RHAZ', 'full_name': 'Rear Hazard Avoidance Camera'}]}}]}

# %%
import requests
resposta = requests.get('https://api.nasa.gov/mars-photos/api/v1/rovers/opportunity/photos?sol=2010&api_key=CuAHy0N4jOGGfel1p7TAM10KLmRBoBIInehXOn86')
resposta.json()
if resposta.status_code == 200:
  fotos = resposta.json()['photos']
  for i, foto in enumerate(fotos, 1):
        print(f"Imagem {i}: {foto['img_src']}")
else:
    print(f"Erro na requisição: {resposta.status_code}")
# Out:
# Imagem 1: http://mars.nasa.gov/mer/gallery/all/1/p/2010/1P306620841EFFA600P2410L2M1-BR.JPG
# Imagem 2: http://mars.nasa.gov/mer/gallery/all/1/p/2010/1P306620841EFFA600P2410R2M1-BR.JPG
# Imagem 3: http://mars.nasa.gov/mer/gallery/all/1/p/2010/1P306620883EFFA600P2410L5M1-BR.JPG
# Imagem 4: http://mars.nasa.gov/mer/gallery/all/1/p/2010/1P306620911EFFA600P2410L7M1-BR.JPG
# Imagem 5: http://mars.nasa.gov/mer/gallery/all/1/p/2010/1P306620938EFFA600P2410L2M1-BR.JPG
# Imagem 6: http://mars.nasa.gov/mer/gallery/all/1/p/2010/1P306620938EFFA600P2410R2M1-BR.JPG
# Imagem 7: http://mars.nasa.gov/mer/gallery/all/1/p/2010/1P306620938EFFA600P2410R2M2-BR.JPG
# Imagem 8: http://mars.nasa.gov/mer/gallery/all/1/p/2010/1P306620969EFFA600P2410L5M1-BR.JPG
# Imagem 9: http://mars.nasa.gov/mer/gallery/all/1/p/2010/1P306620997EFFA600P2410L7M1-BR.JPG
# Imagem 10: http://mars.nasa.gov/mer/gallery/all/1/p/2010/1P306621018EFFA600P2410L2M1-BR.JPG
# Imagem 11: http://mars.nasa.gov/mer/gallery/all/1/p/2010/1P306621018EFFA600P2410R2M1-BR.JPG
# Imagem 12: http://mars.nasa.gov/mer/gallery/all/1/p/2010/1P306621049EFFA600P2410L5M1-BR.JPG
# Imagem 13: http://mars.nasa.gov/mer/gallery/all/1/p/2010/1P306621077EFFA600P2410L7M1-BR.JPG
# Imagem 14: http://mars.nasa.gov/mer/gallery/all/1/p/2010/1P306621124EFFA600P2410L2M1-BR.JPG
# Imagem 15: http://mars.nasa.gov/mer/gallery/all/1/p/2010/1P306621124EFFA600P2410R2M1-BR.JPG
# Imagem 16: http://mars.nasa.gov/mer/gallery/all/1/p/2010/1P306621228EFFA600P2410L5M1-BR.JPG
# Imagem 17: http://mars.nasa.gov/mer/gallery/all/1/p/2010/1P306621299EFFA600P2410L7M1-BR.JPG
# Imagem 18: http://mars.nasa.gov/mer/gallery/all/1/p/2010/1P306621476EFFA600P2410L2M1-BR.JPG
# Imagem 19: http://mars.nasa.gov/mer/gallery/all/1/p/2010/1P306621476EFFA600P2410R2M1-BR.JPG
# Imagem 20: http://mars.nasa.gov/mer/gallery/all/1/p/2010/1P306621567EFFA600P2410L5M1-BR.JPG
# Imagem 21: http://mars.nasa.gov/mer/gallery/all/1/p/2010/1P306621646EFFA600P2410L7M1-BR.JPG
# Imagem 22: http://mars.nasa.gov/mer/gallery/all/1/p/2010/1P306621829EFFA600P2410L2M1-BR.JPG
# Imagem 23: http://mars.nasa.gov/mer/gallery/all/1/p/2010/1P306621829EFFA600P2410R2M1-BR.JPG
# Imagem 24: http://mars.nasa.gov/mer/gallery/all/1/p/2010/1P306621914EFFA600P2410L5M1-BR.JPG
# Imagem 25: http://mars.nasa.gov/mer/gallery/all/1/p/2010/1P306621998EFFA600P2410L7M1-BR.JPG
# Imagem 26: http://mars.nasa.gov/mer/gallery/all/1/p/2010/1P306622172EFFA600P2410L2M1-BR.JPG
# Imagem 27: http://mars.nasa.gov/mer/gallery/all/1/p/2010/1P306622172EFFA600P2410R2M1-BR.JPG
# Imagem 28: http://mars.nasa.gov/mer/gallery/all/1/p/2010/1P306622242EFFA600P2410L5M1-BR.JPG
# Imagem 29: http://mars.nasa.gov/mer/gallery/all/1/p/2010/1P306622320EFFA600P2410L7M1-BR.JPG
# Imagem 30: http://mars.nasa.gov/mer/gallery/all/1/p/2010/1P306622480EFFA600P2410L2M1-BR.JPG
# Imagem 31: http://mars.nasa.gov/mer/gallery/all/1/p/2010/1P306622480EFFA600P2410R2M1-BR.JPG
# Imagem 32: http://mars.nasa.gov/mer/gallery/all/1/p/2010/1P306622571EFFA600P2410L5M1-BR.JPG
# Imagem 33: http://mars.nasa.gov/mer/gallery/all/1/p/2010/1P306622645EFFA600P2410L7M1-BR.JPG
# Imagem 34: http://mars.nasa.gov/mer/gallery/all/1/p/2010/1P306622804EFFA600P2410L2M1-BR.JPG
# Imagem 35: http://mars.nasa.gov/mer/gallery/all/1/p/2010/1P306622804EFFA600P2410R2M1-BR.JPG
# Imagem 36: http://mars.nasa.gov/mer/gallery/all/1/p/2010/1P306622894EFFA600P2410L5M1-BR.JPG
# Imagem 37: http://mars.nasa.gov/mer/gallery/all/1/p/2010/1P306622970EFFA600P2410L7M1-BR.JPG
# Imagem 38: http://mars.nasa.gov/mer/gallery/all/1/p/2010/1P306623129EFFA600P2410L2M1-BR.JPG
# Imagem 39: http://mars.nasa.gov/mer/gallery/all/1/p/2010/1P306623129EFFA600P2410L2M2-BR.JPG
# Imagem 40: http://mars.nasa.gov/mer/gallery/all/1/p/2010/1P306623129EFFA600P2410L2M3-BR.JPG
# Imagem 41: http://mars.nasa.gov/mer/gallery/all/1/p/2010/1P306623129EFFA600P2410L2M4-BR.JPG
# Imagem 42: http://mars.nasa.gov/mer/gallery/all/1/p/2010/1P306623129EFFA600P2410R2M1-BR.JPG
# Imagem 43: http://mars.nasa.gov/mer/gallery/all/1/p/2010/1P306623129EFFA600P2410R2M2-BR.JPG
# Imagem 44: http://mars.nasa.gov/mer/gallery/all/1/p/2010/1P306623218EFFA600P2410L5M1-BR.JPG
# Imagem 45: http://mars.nasa.gov/mer/gallery/all/1/p/2010/1P306623297EFFA600P2410L7M1-BR.JPG
# Imagem 46: http://mars.nasa.gov/mer/gallery/all/1/p/2010/1P306623470EFFA600P2410L2M1-BR.JPG
# Imagem 47: http://mars.nasa.gov/mer/gallery/all/1/p/2010/1P306623470EFFA600P2410R2M1-BR.JPG
# Imagem 48: http://mars.nasa.gov/mer/gallery/all/1/p/2010/1P306623545EFFA600P2410L5M1-BR.JPG
# Imagem 49: http://mars.nasa.gov/mer/gallery/all/1/p/2010/1P306623545EFFA600P2410L5M2-BR.JPG
# Imagem 50: http://mars.nasa.gov/mer/gallery/all/1/p/2010/1P306623545EFFA600P2410L5M3-BR.JPG
# Imagem 51: http://mars.nasa.gov/mer/gallery/all/1/p/2010/1P306623621EFFA600P2410L7M1-BR.JPG
# Imagem 52: http://mars.nasa.gov/mer/gallery/all/1/p/2010/1P306623780EFFA600P2410L2M1-BR.JPG
# Imagem 53: http://mars.nasa.gov/mer/gallery/all/1/p/2010/1P306623780EFFA600P2410R2M1-BR.JPG
# Imagem 54: http://mars.nasa.gov/mer/gallery/all/1/p/2010/1P306623873EFFA600P2410L5M1-BR.JPG
# Imagem 55: http://mars.nasa.gov/mer/gallery/all/1/p/2010/1P306623945EFFA600P2410L7M1-BR.JPG
# Imagem 56: http://mars.nasa.gov/mer/gallery/all/1/p/2010/1P306624118EFFA600P2410L2M1-BR.JPG
# Imagem 57: http://mars.nasa.gov/mer/gallery/all/1/p/2010/1P306624118EFFA600P2410L2M2-BR.JPG
# Imagem 58: http://mars.nasa.gov/mer/gallery/all/1/p/2010/1P306624118EFFA600P2410L2M3-BR.JPG
# Imagem 59: http://mars.nasa.gov/mer/gallery/all/1/p/2010/1P306624118EFFA600P2410R2M1-BR.JPG
# Imagem 60: http://mars.nasa.gov/mer/gallery/all/1/p/2010/1P306624207EFFA600P2410L5M1-BR.JPG
# Imagem 61: http://mars.nasa.gov/mer/gallery/all/1/p/2010/1P306624283EFFA600P2410L7M1-BR.JPG
# Imagem 62: http://mars.nasa.gov/mer/gallery/all/1/p/2010/1P306624455EFFA600P2410L2M1-BR.JPG
# Imagem 63: http://mars.nasa.gov/mer/gallery/all/1/p/2010/1P306624455EFFA600P2410R2M1-BR.JPG
# Imagem 64: http://mars.nasa.gov/mer/gallery/all/1/p/2010/1P306624455EFFA600P2410R2M2-BR.JPG
# Imagem 65: http://mars.nasa.gov/mer/gallery/all/1/p/2010/1P306624455EFFA600P2410R2M3-BR.JPG
# Imagem 66: http://mars.nasa.gov/mer/gallery/all/1/p/2010/1P306624531EFFA600P2410L5M1-BR.JPG
# Imagem 67: http://mars.nasa.gov/mer/gallery/all/1/p/2010/1P306624616EFFA600P2410L7M1-BR.JPG
# Imagem 68: http://mars.nasa.gov/mer/gallery/all/1/p/2010/1P306624794EFFA600P2410L2M1-BR.JPG
# Imagem 69: http://mars.nasa.gov/mer/gallery/all/1/p/2010/1P306624794EFFA600P2410R2M1-BR.JPG
# Imagem 70: http://mars.nasa.gov/mer/gallery/all/1/p/2010/1P306624870EFFA600P2410L5M1-BR.JPG
# Imagem 71: http://mars.nasa.gov/mer/gallery/all/1/p/2010/1P306624946EFFA600P2410L7M1-BR.JPG
# Imagem 72: http://mars.nasa.gov/mer/gallery/all/1/p/2010/1P306625108EFFA600P2410L2M1-BR.JPG
# Imagem 73: http://mars.nasa.gov/mer/gallery/all/1/p/2010/1P306625108EFFA600P2410R2M1-BR.JPG
# Imagem 74: http://mars.nasa.gov/mer/gallery/all/1/p/2010/1P306625210EFFA600P2410L5M1-BR.JPG
# Imagem 75: http://mars.nasa.gov/mer/gallery/all/1/p/2010/1P306625287EFFA600P2410L7M1-BR.JPG
# Imagem 76: http://mars.nasa.gov/mer/gallery/all/1/p/2010/1P306625463EFFA600P2410L2M1-BR.JPG
# Imagem 77: http://mars.nasa.gov/mer/gallery/all/1/p/2010/1P306625463EFFA600P2410R2M1-BR.JPG
# Imagem 78: http://mars.nasa.gov/mer/gallery/all/1/p/2010/1P306625552EFFA600P2410L5M1-BR.JPG
# Imagem 79: http://mars.nasa.gov/mer/gallery/all/1/p/2010/1P306625634EFFA600P2410L7M1-BR.JPG
# Imagem 80: http://mars.nasa.gov/mer/gallery/all/1/p/2010/1P306625806EFFA600P2410L2M1-BR.JPG
# Imagem 81: http://mars.nasa.gov/mer/gallery/all/1/p/2010/1P306625806EFFA600P2410R2M1-BR.JPG
# Imagem 82: http://mars.nasa.gov/mer/gallery/all/1/p/2010/1P306625892EFFA600P2410L5M1-BR.JPG
# Imagem 83: http://mars.nasa.gov/mer/gallery/all/1/p/2010/1P306625978EFFA600P2410L7M1-BR.JPG
# Imagem 84: http://mars.nasa.gov/mer/gallery/all/1/p/2010/1P306626158EFFA600P2410L2M1-BR.JPG
# Imagem 85: http://mars.nasa.gov/mer/gallery/all/1/p/2010/1P306626158EFFA600P2410R2M1-BR.JPG
# Imagem 86: http://mars.nasa.gov/mer/gallery/all/1/p/2010/1P306626242EFFA600P2410L5M1-BR.JPG
# Imagem 87: http://mars.nasa.gov/mer/gallery/all/1/p/2010/1P306626322EFFA600P2410L7M1-BR.JPG
# Imagem 88: http://mars.nasa.gov/mer/gallery/all/1/p/2010/1P306626487EFFA600P2410L2M1-BR.JPG
# Imagem 89: http://mars.nasa.gov/mer/gallery/all/1/p/2010/1P306626487EFFA600P2410R2M1-BR.JPG
# Imagem 90: http://mars.nasa.gov/mer/gallery/all/1/p/2010/1P306626579EFFA600P2410L5M1-BR.JPG
# Imagem 91: http://mars.nasa.gov/mer/gallery/all/1/p/2010/1P306626652EFFA600P2410L7M1-BR.JPG
# Imagem 92: http://mars.nasa.gov/mer/gallery/all/1/p/2010/1P306626812EFFA600P2410L2M1-BR.JPG
# Imagem 93: http://mars.nasa.gov/mer/gallery/all/1/p/2010/1P306626812EFFA600P2410R2M1-BR.JPG
# Imagem 94: http://mars.nasa.gov/mer/gallery/all/1/p/2010/1P306626902EFFA600P2410L5M1-BR.JPG
# Imagem 95: http://mars.nasa.gov/mer/gallery/all/1/p/2010/1P306626976EFFA600P2410L7M1-BR.JPG
# Imagem 96: http://mars.nasa.gov/mer/gallery/all/1/p/2010/1P306627153EFFA600P2410L2M1-BR.JPG
# Imagem 97: http://mars.nasa.gov/mer/gallery/all/1/p/2010/1P306627153EFFA600P2410R2M1-BR.JPG
# Imagem 98: http://mars.nasa.gov/mer/gallery/all/1/p/2010/1P306627230EFFA600P2410L5M1-BR.JPG
# Imagem 99: http://mars.nasa.gov/mer/gallery/all/1/p/2010/1P306627312EFFA600P2410L7M1-BR.JPG
